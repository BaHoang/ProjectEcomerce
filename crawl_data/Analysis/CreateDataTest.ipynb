"63c82acfe970f0eed5dff9f7", "63c82adde970f0eed5dffa3c",
"63c82c03e970f0eed5dfff25", "63c82acfe970f0eed5dff9f7",
"63c82acee970f0eed5dff9f1", "63c82adce970f0eed5dffa35",
"63c82841e970f0eed5dff85b", "63c82a03e970f0eed5dff957",
"63c82bb1e970f0eed5dffd84", "63c82c00e970f0eed5dfff11",
"63c82c0ee970f0eed5dfff98", "63c82bd9e970f0eed5dffe3a",
"63c829b4e970f0eed5dff8e8", "63c829b9e970f0eed5dff8eb",
"63c82acbe970f0eed5dff9e2", "63c82baee970f0eed5dffd72",
"63c82acbe970f0eed5dff9e5", "63c82ad1e970f0eed5dff9ff",
"63c82b83e970f0eed5dffcb8", "63c82b83e970f0eed5dffcb4",
"63c82b64e970f0eed5dffba9", "63c82bd7e970f0eed5dffe32"]

array_not_match_20 = ["63c8283fe970f0eed5dff84c", "63c82b5ae970f0eed5dffb32", 
    "63c8283fe970f0eed5dff84d", "63c82b64e970f0eed5dffba4", 
    "63c8283fe970f0eed5dff84d", "63c82846e970f0eed5dff881", 
    "63c8283fe970f0eed5dff84d", "63c82ba1e970f0eed5dffd2d", 
    "63c82adbe970f0eed5dffa33", "63c82bcae970f0eed5dffdf2", 
    "63c82b5ee970f0eed5dffb59", "63c82b85e970f0eed5dffccc", 
    "63c82bcee970f0eed5dffe05", "63c82bcfe970f0eed5dffe0c", 
    "63c82abfe970f0eed5dff9ad", "63c82abfe970f0eed5dff9ae", 
    "63c82abfe970f0eed5dff9ad", "63c82adae970f0eed5dffa2d", 
    "63c82ac0e970f0eed5dff9b3", "63c82ac0e970f0eed5dff9b4", 
    "63c82bd0e970f0eed5dffe0f", "63c82bd1e970f0eed5dffe15", 
    "63c82bd0e970f0eed5dffe10", "63c82bd0e970f0eed5dffe11", 
    "63c82bd1e970f0eed5dffe15", "63c82bd2e970f0eed5dffe18", 
    "63c82bd0e970f0eed5dffe10", "63c82bd2e970f0eed5dffe16", 
    "63c82bd0e970f0eed5dffe11", "63c82bd2e970f0eed5dffe17", 
    "63c82abbe970f0eed5dff994", "63c82b60e970f0eed5dffb7b", 
    "63c82b60e970f0eed5dffb75", "63c82b60e970f0eed5dffb7b", 
    "63c82840e970f0eed5dff852", "63c82abae970f0eed5dff98b", 
    "63c82841e970f0eed5dff859", "63c82abce970f0eed5dff996", 
    "63c829ade970f0eed5dff8da", "63c82b95e970f0eed5dffcf2"]

# %%
# import random

# # first_match 
# # second_match 
# # label_match 

# list_first_item = []
# for id in first_match:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_first_item.append(item)


# list_second_item = []
# for id in second_match:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_second_item.append(item)

# for item in list_first_item:
#     item['_id'] = str(item['_id'])

# for item in list_second_item:
#     item['_id'] = str(item['_id'])

# import json
# with open('data_first_match.json', 'w', encoding='utf-8') as f:
#     json.dump(list_first_item, f, ensure_ascii=False)

# with open('data_second_match.json', 'w', encoding='utf-8') as f:
#     json.dump(list_second_item, f, ensure_ascii=False)

# %%
# import random

# # first_not_match
# # second_not_match 
# # label_not_match


# list_first_not_item = []
# for id in first_not_match:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_first_not_item.append(item)
#             break

# list_second_not_item = []
# for id in second_not_match:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_second_not_item.append(item)
#             break


# for item in list_first_not_item:
#     item['_id'] = str(item['_id'])

# for item in list_second_not_item:
#     item['_id'] = str(item['_id'])

# import json
# with open('data_first_not_match.json', 'w', encoding='utf-8') as f:
#     json.dump(list_first_not_item, f, ensure_ascii=False)

# with open('data_second_not_match.json', 'w', encoding='utf-8') as f:
#     json.dump(list_second_not_item, f, ensure_ascii=False)

# %%
tao datatest va danh gia thuat toan voi do do su dung la recal precision f1-score


1. tao dataset
1.1 tao duoc 200 cai khong khop
1.2 tao duoc 100 cai trong do co 75 cai khop va 25 cai khong khop
2. do do su dung
2.1 recall
2.2 precision
2.3 f1-score


cac buoc tiep theo phai lam

ok check trong 200 cai vua tao co cai nao thieu cac truong du lieu khong (name, linkProduct, brand, rom, ram, priceDiscount, color) -> neu thieu mot trong 
   nhung truong du lieu cua 1 phan tu trong cap thi ta se loai cap do luon

ok read data da luu duoi dang json
ok su dung ham check da tao

doc tat ca data
concat tat ca lai voi nhau

# %%
import json
with open('data_first.json', encoding='utf-8') as f:
    data_first = json.load(f)

with open('data_second.json', encoding='utf-8') as f:
    data_second = json.load(f)

def check_item(item):
  check = True
  if ('name' in item.keys() and item['name'] == '') or 'name' not in item.keys():
    check = False
    print("name")

  if 'linkProduct' not in item.keys() or ('linkProduct' in item.keys() and item['linkProduct'] == ''):
    check = False
    print("linkProduct")
  
  if 'brand' not in item.keys() or ('brand' in item.keys() and item['brand'] == ''):
    check = False
    print("brand")
  
  if 'rom' not in item.keys() or ('rom' in item.keys() and item['rom'] == None):
    check = False
    print("rom")
  
  if 'ram' not in item.keys() or ('ram' in item.keys() and item['ram'] == None):
    check = False
    print("ram")
  if 'priceDiscount' in item.keys():
    if item['priceDiscount'] == '0':
      check = False  
      print("linkProduct")

  return check

count = 0
for i in range(len(data_first)):
    check_first = check_item(data_first[i])
    check_second = check_item(data_second[i])

    if not (check_first and check_second):
        count += 1
        # print(data_first[i], data_second[i])

print(count)

# %%
# import json
# with open('data_first.json', encoding='utf-8') as f:
#     data_first = json.load(f)

# with open('data_second.json', encoding='utf-8') as f:
#     data_second = json.load(f)
    
# for i in range(len(data_first)):
#     print("********************************************************************************************************************************************************************")
#     print("Số Thứ Tự", i+1)
#     if "namePage" in data_first[i] and "namePage" in data_second[i]:
#         print(data_first[i]["namePage"], "||", data_second[i]["namePage"])
    
#     if "name" in data_first[i] and "name" in data_second[i]:
#         print(data_first[i]["name"], "||", data_second[i]["name"])
    
#     if "brand" in data_first[i] and "brand" in data_second[i]:
#         print(data_first[i]["brand"], "||", data_second[i]["brand"])
    
#     if "ram" in data_first[i] and "ram" in data_second[i]:
#         print(data_first[i]["ram"], "||", data_second[i]["ram"])
    
#     if "rom" in data_first[i] and "rom" in data_second[i]:
#         print(data_first[i]["rom"], "||", data_second[i]["rom"])
    
#     if "color" in data_first[i] and "color" in data_second[i]:
#         print(data_first[i]["color"], "||", data_second[i]["color"])
    
#     if "price" in data_first[i] and "price" in data_second[i]:
#         print(data_first[i]["price"], "||", data_second[i]["price"])
    
#     if "priceDiscount" in data_first[i] and "priceDiscount" in data_second[i]:
#         print(data_first[i]["priceDiscount"], "||", data_second[i]["priceDiscount"])
    
#     if "linkProduct" in data_first[i] and "linkProduct" in data_second[i]:
#         print(data_first[i]["linkProduct"], "||", data_second[i]["linkProduct"])
    
#     if "pin" in data_first[i] and "pin" in data_second[i]:
#         print(data_first[i]["pin"], "||", data_second[i]["pin"])
    
#     if "cameraTruoc" in data_first[i] and "cameraTruoc" in data_second[i]:
#         print(data_first[i]["cameraTruoc"], "||", data_second[i]["cameraTruoc"])
    
#     if "cameraSau" in data_first[i] and "cameraSau" in data_second[i]:
#         print(data_first[i]["cameraSau"], "||", data_second[i]["cameraSau"])
    
#     if "chipset" in data_first[i] and "chipset" in data_second[i]:
#         print(data_first[i]["chipset"], "||", data_second[i]["chipset"])
    
#     if "operating" in data_first[i] and "operating" in data_second[i]:
#         print(data_first[i]["operating"], "||", data_second[i]["operating"])
    
#     if "manHinh" in data_first[i] and "manHinh" in data_second[i]:
#         print(data_first[i]["manHinh"], "||", data_second[i]["manHinh"])

# %%
# import re
# from pymongo import MongoClient
# import pandas as pd
# import numpy

# client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
# db = client.get_database('data_phone_db')
# phones = db.data_phone_items
# list_database = []
# for item in list(phones.find()):
#     list_database.append(item)

# def clean_brand(brand):
#   brand = str(brand).strip().split()[0].lower()
#   if brand == 'iphone':
#     brand = 'apple'
#   return brand

# def clean_price_discount(priceDiscount, check):
#   if check:
#     list_word = ["Liên", "hệ"]
#     priceDiscount = str(priceDiscount).strip().replace('.', '').replace('đ', '')
#     for word in list_word:
#       if word in priceDiscount:
#           priceDiscount = 0
#           break
#     return str(priceDiscount)
#   else:
#     priceDiscount = str(priceDiscount).strip().replace('đ', '').split('.')[0]
#     return str(priceDiscount)

# def clean_price(price, check):
#   if check:
#     price = str(price).strip().replace('.', '').replace('đ', '')
#   else:
#     price = str(price).strip().replace('đ', '').split('.')[0]
#   return str(price)

# def clean_ram(ram):
#   ram = str(ram).strip().upper()
#   if 'GB' in ram or 'G' in ram:
#     ram = ram.split()[0].replace('G', '').replace('B', '').replace('+','')
#     ram = re.sub("\(.*\)", "", ram)
#     ram = re.sub("\,", "", ram)
#     if ram != '' and ram.isnumeric():
#       ram = ram + "GB"
#       return ram
  
#   if 'MB' in ram or 'M' in ram:
#     ram = ram.split()[0].replace('M', '').replace('B', '').replace('+','')
#     ram = re.sub("\(.*\)", "", ram)
#     ram = re.sub("\,", "", ram)
#     if ram != '' and ram.isnumeric():
#       ram = ram + "MB"
#       return ram

#   return ""

# def preprocessing_ram(item):
#   if ("ram" not in item) or ("ram" in item and item["ram"] == None) :
#     name = item["name"].lower()
#     check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
#     if check_have_ram_rom:
#         ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]

#         if '-' in ram_rom:
#             ram = re.split('[-]', ram_rom)[0]
#             item["ram"] = clean_ram(ram)
#         elif '|' in ram_rom:
#             ram = re.split('[|]', ram_rom)[0]
#             item["ram"] = clean_ram(ram)
#         elif '/' in ram_rom:
#             ram = re.split('[/]', ram_rom)[0]
#             item["ram"] = clean_ram(ram)
#         else:
#             ram = re.split('[\s]', ram_rom)[0]    
#             item["ram"] = clean_ram(ram) 
  
#   if "ram" in item:
#     item['ram'] = clean_ram(item['ram'])

# def clean_rom(rom):
#   rom = str(rom).strip().upper()
#   if 'GB' in rom or 'G' in rom:
#     rom = rom.split()[0].replace('G', '').replace('B', '')
#     rom = re.sub("\(.*\)", "", rom)
#     rom = re.sub("\,", "", rom)
#     if rom != '' and rom.isnumeric():
#       rom = rom + "GB"
#       return rom
  
#   if 'MB' in rom or 'M' in rom:
#     rom = rom.split()[0].replace('M', '').replace('B', '')
#     rom = re.sub("\(.*\)", "", rom)
#     rom = re.sub("\,", "", rom)
#     if rom != '' and rom.isnumeric():
#       rom = rom + "MB"
#       return rom
  
#   if 'TB' in rom or 'T' in rom:
#     rom = rom.split()[0].replace('T', '').replace('B', '')
#     rom = re.sub("\(.*\)", "", rom)
#     rom = re.sub("\,", "", rom)
#     if rom != '' and rom.isnumeric():
#       rom = rom + "TB"
#       return rom

#   return ""

# def preprocessing_rom(item):
#   if ("rom" not in item) or ("rom" in item and item["rom"] == None):
#     name = item["name"].lower()
#     check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
#     if check_have_ram_rom:
#         ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]
#         if '-' in ram_rom:
#             rom = re.split('[-]', ram_rom)[-1]
#             item["rom"] = rom
#         elif '|' in ram_rom:
#             rom = re.split('[|]', ram_rom)[-1]
#             item["rom"] = rom
#         elif '/' in ram_rom:
#             rom = re.split('[/]', ram_rom)[-1]
#             item["rom"] = rom
#         else:
#             rom = re.split('[\s]', ram_rom)[-1]    
#             item["rom"] = rom   
#     else:
#         check_have_rom = re.search("[0-9]+[tmg][b]", name)
#         if check_have_rom:
#             rom = re.findall("[0-9]+[tmg][b]", name)[0]
#             item["rom"] = rom
  
#   if "rom" in item:
#     item['rom'] = clean_rom(item['rom'])

# def clean_data(item):
  
#   if 'brand' in item.keys():
#     item['brand'] = clean_brand(item['brand'])

#   preprocessing_ram(item)
#   preprocessing_rom(item)
    
#   if 'price' in item.keys():
#     if item['namePage'] == 'CellphoneS':
#         item['price'] = clean_price(item['price'], False)
#     else:
#         item['price'] = clean_price(item['price'], True)

#   if 'priceDiscount' in item.keys():
#     if item['namePage'] == 'CellphoneS':
#         item['priceDiscount'] = clean_price_discount(item['priceDiscount'], False)
#     else:
#         item['priceDiscount'] = clean_price_discount(item['priceDiscount'], True)

#   if 'cameraSau' in item.keys():
#     item['cameraSau'] = str(item['cameraSau']).strip()
  
#   if 'cameraTruoc' in item.keys():
#     item['cameraTruoc'] = str(item['cameraTruoc']).strip()
  
#   if 'chipset' in item.keys():
#     item['chipset'] = str(item['chipset']).strip()

#   if 'color' in item.keys():
#     item['color'] = str(item['color']).strip()
  
#   if 'image' in item.keys():
#     item['image'] = str(item['image']).strip()
  
#   if 'linkProduct' in item.keys():
#     item['linkProduct'] = str(item['linkProduct']).strip()
  
#   if 'manHinh' in item.keys():
#     item['manHinh'] = str(item['manHinh']).strip()

#   if 'name' in item.keys():
#     item['name'] = str(item['name']).strip()
  
#   if 'operating' in item.keys():
#     item['operating'] = str(item['operating']).strip()
  
#   if 'pin' in item.keys():
#     item['pin'] = str(item['pin']).strip()

# for item in list_database:
#   clean_data(item)

# def check_item(item):
#   check = True
#   if 'name' in item.keys():
#     if item['name'] == '':
#       check = False

#   if 'linkProduct' in item.keys():
#     if item['linkProduct'] == '':
#       check = False
  
#   if 'brand' in item.keys():
#     if item['brand'] == '':
#       check = False
  
#   if 'rom' not in item.keys() or ('rom' in item.keys() and item['rom'] == ''):
#     check = False
  
#   if 'ram' not in item.keys() or ('ram' in item.keys() and item['ram'] == ''):
#     check = False
  
#   if 'priceDiscount' in item.keys():
#     if item['priceDiscount'] == '0':
#       check = False  

#   return check

# list_database_new = []
# for item in list_database:
#   if check_item(item):
#     list_database_new.append(item)

# %% [markdown]
# # Create random list

# %%
# import random
# list_first = random.sample(range(0, 1776), 200)
# list_second = random.sample(range(0, 1776), 200)
# list_first_id = []
# for i in list_first:
#     list_first_id.append(str(list_database_new[i]["_id"]))
    
# list_second_id = []
# for i in list_second:
#     list_second_id.append(str(list_database_new[i]["_id"]))

# list_first_item = []
# for id in list_first_id:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_first_item.append(item)

# list_second_item = []
# for id in list_second_id:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_second_item.append(item)

# for item in list_first_item:
#     item['_id'] = str(item['_id'])

# for item in list_second_item:
#     item['_id'] = str(item['_id'])

# import json
# with open('data_first.json', 'w', encoding='utf-8') as f:
#     json.dump(list_first_item, f, ensure_ascii=False)

# import json
# with open('data_second.json', 'w', encoding='utf-8') as f:
#     json.dump(list_second_item, f, ensure_ascii=False)

# %%
# array_not_match_20 =["63c8283fe970f0eed5dff84c", "63c82b5ae970f0eed5dffb32", 
#     "63c8283fe970f0eed5dff84d", "63c82b64e970f0eed5dffba4", 
#     "63c8283fe970f0eed5dff84d", "63c82846e970f0eed5dff881", 
#     "63c8283fe970f0eed5dff84d", "63c82ba1e970f0eed5dffd2d", 
#     "63c82adbe970f0eed5dffa33", "63c82bcae970f0eed5dffdf2", 
#     "63c82b5ee970f0eed5dffb59", "63c82b85e970f0eed5dffccc", 
#     "63c82bcee970f0eed5dffe05", "63c82bcfe970f0eed5dffe0c", 
#     "63c82abfe970f0eed5dff9ad", "63c82abfe970f0eed5dff9ae", 
#     "63c82abfe970f0eed5dff9ad", "63c82adae970f0eed5dffa2d", 
#     "63c82ac0e970f0eed5dff9b3", "63c82ac0e970f0eed5dff9b4", 
#     "63c82bd0e970f0eed5dffe0f", "63c82bd1e970f0eed5dffe15", 
#     "63c82bd0e970f0eed5dffe10", "63c82bd0e970f0eed5dffe11", 
#     "63c82bd1e970f0eed5dffe15", "63c82bd2e970f0eed5dffe18", 
#     "63c82bd0e970f0eed5dffe10", "63c82bd2e970f0eed5dffe16", 
#     "63c82bd0e970f0eed5dffe11", "63c82bd2e970f0eed5dffe17", 
#     "63c82abbe970f0eed5dff994", "63c82b60e970f0eed5dffb7b", 
#     "63c82b60e970f0eed5dffb75", "63c82b60e970f0eed5dffb7b", 
#     "63c82840e970f0eed5dff852", "63c82abae970f0eed5dff98b", 
#     "63c82841e970f0eed5dff859", "63c82abce970f0eed5dff996", 
#     "63c829ade970f0eed5dff8da", "63c82b95e970f0eed5dffcf2"]

# first_not_match_20 = []
# for i in range(len(array_not_match_20)):
#     if i % 2 == 0:
#         first_not_match_20.append(array_not_match_20[i])

# second_not_match_20 = []
# for i in range(len(array_not_match_20)):
#     if i % 2 == 1:
#         second_not_match_20.append(array_not_match_20[i])

# label_not_match_20 =  [0 for i in range(len(first_not_match_20))] 

# list_first_not_item_20 = []
# for id in first_not_match_20:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_first_not_item_20.append(item)
#             break

# list_second_not_item_20 = []
# for id in second_not_match_20:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_second_not_item_20.append(item)
#             break

# for item in list_first_not_item_20:
#     item['_id'] = str(item['_id'])

# for item in list_second_not_item_20:
#     item['_id'] = str(item['_id'])
    
# with open('data_first_not_match_20.json', 'w', encoding='utf-8') as f:
#     json.dump(list_first_not_item_20, f, ensure_ascii=False)

# with open('data_second_not_match_20.json', 'w', encoding='utf-8') as f:
#     json.dump(list_second_not_item_20, f, ensure_ascii=False)

# %%
# first_match_1 = ["63c82be1e970f0eed5dffe61"]
# second_match_1 = ["63c82b6ae970f0eed5dffbea"]
# label_match_1 =  [1] 

# list_first_item_1 = []
# for id in first_match_1:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_first_item_1.append(item)
#             break

# list_second_item_1 = []
# for id in second_match_1:
#     for item in list_database:
#         if str(item['_id']) == id:
#             list_second_item_1.append(item)
#             break

# for item in list_first_item_1:
#     item['_id'] = str(item['_id'])

# for item in list_second_item_1:
#     item['_id'] = str(item['_id'])

# with open('data_first_match_1.json', 'w', encoding='utf-8') as f:
#     json.dump(list_first_item_1, f, ensure_ascii=False)

# with open('data_second_match_1.json', 'w', encoding='utf-8') as f:
#     json.dump(list_second_item_1, f, ensure_ascii=False)

# %% [markdown]
# # QUAN TRONG
# ## Code tao data_final

# %%
# QUAN TRONG
# data_first_200_not_match
# data_first_25_not_match
# data_first_75_match
# data_first_20_not_match
# data_first_1_match

# data_second_200_not_match
# data_second_25_not_match
# data_second_75_match
# data_second_20_not_match
# data_second_1_match

# ========================== CREATE DATA FINAL (CREATED COMMENT) ===============================================

# import json
# with open('data_first.json', encoding='utf-8') as f:
#     data_first_200_not_match = json.load(f)

# with open('data_second.json', encoding='utf-8') as f:
#     data_second_200_not_match = json.load(f)

# with open('data_first_not_match.json', encoding='utf-8') as f:
#     data_first_25_not_match = json.load(f)

# with open('data_second_not_match.json', encoding='utf-8') as f:
#     data_second_25_not_match = json.load(f)

# with open('data_first_match.json', encoding='utf-8') as f:
#     data_first_75_match = json.load(f)

# with open('data_second_match.json', encoding='utf-8') as f:
#     data_second_75_match = json.load(f)

# with open('data_first_not_match_20.json', encoding='utf-8') as f:
#     data_first_20_not_match = json.load(f)

# with open('data_second_not_match_20.json', encoding='utf-8') as f:
#     data_second_20_not_match = json.load(f)

# with open('data_first_match_1.json', encoding='utf-8') as f:
#     data_first_1_match = json.load(f)

# with open('data_second_match_1.json', encoding='utf-8') as f:
#     data_second_1_match = json.load(f)

# label_200_not_match = [0 for i in range(200)] 
# label_25_not_match = [0 for i in range(25)]
# label_75_match = [1 for i in range(75)]
# label_20_not_match = [0 for i in range(20)]
# label_1_match = [1 for i in range(1)]
# data_first = data_first_200_not_match + data_first_25_not_match + data_first_75_match + data_first_20_not_match + data_first_1_match
# data_second = data_second_200_not_match + data_second_25_not_match + data_second_75_match + data_second_20_not_match + data_second_1_match
# label = label_200_not_match + label_25_not_match + label_75_match + label_20_not_match + label_1_match

# with open('data_first_final.json', 'w', encoding='utf-8') as f:
#     json.dump(data_first, f, ensure_ascii=False)

# with open('data_second_final.json', 'w', encoding='utf-8') as f:
#     json.dump(data_second, f, ensure_ascii=False)

# with open('label_final.json', 'w', encoding='utf-8') as f:
#     json.dump(label, f, ensure_ascii=False)

# ====================================== READ DATA AND LABEL ====================================================

import json
with open('data_first_final.json', encoding='utf-8') as f:
    data_first_final = json.load(f)

with open('data_second_final.json', encoding='utf-8') as f:
    data_second_final = json.load(f)

with open('label_final.json', encoding='utf-8') as f:
    label_final = json.load(f)

# %%
# list_match_first = ["63c82849e970f0eed5dff897", "63c82bc5e970f0eed5dffde1", "63c82bc5e970f0eed5dffde1", "63c82b68e970f0eed5dffbd2", "63c82be1e970f0eed5dffe61" ]
# list_match_second = ["63c82b67e970f0eed5dffbcf", "63c82b67e970f0eed5dffbcf", "63c82849e970f0eed5dff897", "63c82bc6e970f0eed5dffde3", "63c82b6ae970f0eed5dffbea"]

# %% [markdown]
# # TEST

# %%
import re

def clean_brand(brand):
  brand = str(brand).strip().split()[0].lower()
  if brand == 'iphone':
    brand = 'apple'
  return brand

def clean_price_discount(priceDiscount, check):
  if check:
    list_word = ["Liên", "hệ"]
    priceDiscount = str(priceDiscount).strip().replace('.', '').replace('đ', '')
    for word in list_word:
      if word in priceDiscount:
          priceDiscount = 0
          break
    return str(priceDiscount)
  else:
    priceDiscount = str(priceDiscount).strip().replace('đ', '').split('.')[0]
    return str(priceDiscount)

def clean_price(price, check):
  if check:
    price = str(price).strip().replace('.', '').replace('đ', '')
  else:
    price = str(price).strip().replace('đ', '').split('.')[0]
  return str(price)

def clean_ram(ram):
  ram = str(ram).strip().upper()
  if 'GB' in ram or 'G' in ram:
    ram = ram.split()[0].replace('G', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "GB"
      return ram
  
  if 'MB' in ram or 'M' in ram:
    ram = ram.split()[0].replace('M', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "MB"
      return ram

  return ""

def preprocessing_ram(item):
  if ("ram" not in item) or ("ram" in item and item["ram"] == None) :
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]

        if '-' in ram_rom:
            ram = re.split('[-]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '|' in ram_rom:
            ram = re.split('[|]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '/' in ram_rom:
            ram = re.split('[/]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        else:
            ram = re.split('[\s]', ram_rom)[0]    
            item["ram"] = clean_ram(ram) 
  
  if "ram" in item:
    item['ram'] = clean_ram(item['ram'])

def clean_rom(rom):
  rom = str(rom).strip().upper()
  if 'GB' in rom or 'G' in rom:
    rom = rom.split()[0].replace('G', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "GB"
      return rom
  
  if 'MB' in rom or 'M' in rom:
    rom = rom.split()[0].replace('M', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "MB"
      return rom
  
  if 'TB' in rom or 'T' in rom:
    rom = rom.split()[0].replace('T', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "TB"
      return rom

  return ""

def preprocessing_rom(item):
  if ("rom" not in item) or ("rom" in item and item["rom"] == None):
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]
        if '-' in ram_rom:
            rom = re.split('[-]', ram_rom)[-1]
            item["rom"] = rom
        elif '|' in ram_rom:
            rom = re.split('[|]', ram_rom)[-1]
            item["rom"] = rom
        elif '/' in ram_rom:
            rom = re.split('[/]', ram_rom)[-1]
            item["rom"] = rom
        else:
            rom = re.split('[\s]', ram_rom)[-1]    
            item["rom"] = rom   
    else:
        check_have_rom = re.search("[0-9]+[tmg][b]", name)
        if check_have_rom:
            rom = re.findall("[0-9]+[tmg][b]", name)[0]
            item["rom"] = rom
  
  if "rom" in item:
    item['rom'] = clean_rom(item['rom'])

def clean_data(item):
  if 'brand' in item.keys():
    item['brand'] = clean_brand(item['brand'])

  preprocessing_ram(item)
  preprocessing_rom(item)
    
  if 'price' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['price'] = clean_price(item['price'], False)
    else:
        item['price'] = clean_price(item['price'], True)

  if 'priceDiscount' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], False)
    else:
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], True)

  if 'cameraSau' in item.keys():
    item['cameraSau'] = str(item['cameraSau']).strip()
  
  if 'cameraTruoc' in item.keys():
    item['cameraTruoc'] = str(item['cameraTruoc']).strip()
  
  if 'chipset' in item.keys():
    item['chipset'] = str(item['chipset']).strip()

  if 'color' in item.keys():
    item['color'] = str(item['color']).strip()
  
  if 'image' in item.keys():
    item['image'] = str(item['image']).strip()
  
  if 'linkProduct' in item.keys():
    item['linkProduct'] = str(item['linkProduct']).strip()
  
  if 'manHinh' in item.keys():
    item['manHinh'] = str(item['manHinh']).strip()

  if 'name' in item.keys():
    item['name'] = str(item['name']).strip()
  
  if 'operating' in item.keys():
    item['operating'] = str(item['operating']).strip()
  
  if 'pin' in item.keys():
    item['pin'] = str(item['pin']).strip()

# %%
from fuzzywuzzy import fuzz
import re

def brand_matching (item_one, item_two):
    if "brand" in item_one.keys() and "brand" in item_two.keys():
        brand_one = item_one["brand"]
        brand_two = item_two["brand"]
        if brand_one == brand_two:
            return True
        list_same = ['xiaomi', 'poco', 'redmi']
        if brand_one in list_same and brand_two in list_same:
            return True
    return False

list_color = ['huyền', 'cam', 'đen', 'xanh', 'tím', 'xám', 'ánh', 'kim', 'đồng', 'thiên', 'thạch', 'dương', 'đậm', 'thanh', 'vàng', 'bạc', 'trắng', 'hồng', 'hà', 'lá', 'đỏ', 'kem', 'lục', 'nhạt', 'biển', 'cực', 'quang']
list_brand = ['masstel','itel','nubia', 'tcl', 'vsmart', 'oneplus', 'asus', 'bphone', 'philips', 'samsung', 'galaxy', 'xiaomi', 'apple', 'iphone', 'oppo', 'realme', 'nokia', 'vivo', 'tecno']
list_delete = ["dộng", "box", "chính", "hãng", "vna", "vn/a", "trưng", "bày", "cũ", "gia", "studio", "màu", "mới", "chính", "hãng", "ll", "za", "chính", "hãng"]
def clean_name(name):
    name = name.lower()
    name = name.replace("điện", "").replace("thoại", "")
    name = re.sub("\(.*\)", "", name)
    name = name.split("-")[0]
    name = name.split("–")[0]
    name = name.split("|")[0]
    name = re.sub("\d+[tmg]b(.*\d+[tmg]b)?", "", name)

    for item_delete in list_delete:
        name = name.replace(item_delete, "")
        
    for brand in list_brand:
        name = name.replace(brand, "")
    for color in list_color:
        name = name.replace(color, "")

    # khoang cach giua 2 tu chi la 1 whitespace    
    name = name.split()
    name = ' '.join(name)
    return name

def name_matching (item_one, item_two, threshold):
    if "name" in item_one.keys() and "name" in item_two.keys():
        name_one = item_one["name"]
        name_two = item_two["name"]
        name_one_new = clean_name(name_one)
        name_two_new = clean_name(name_two)

        ratio = fuzz.token_set_ratio(name_one_new, name_two_new)
        # ratio = fuzz.ratio(name_one_new, name_two_new)
        
        if ratio > threshold:
            return True
            
    return False

def ram_matching (item_one, item_two, threshold_ram):

    if "ram" in item_one.keys() and "ram" in item_two.keys():
        ram_one = item_one["ram"]
        ram_two = item_two["ram"]
        ratio = fuzz.ratio(ram_one, ram_two)

        if ratio > threshold_ram:
            return True
        
    return False

def rom_matching (item_one, item_two, threshold_rom):

    if "rom" in item_one.keys() and "rom" in item_two.keys():
        rom_one = item_one["rom"]
        rom_two = item_two["rom"]
        ratio = fuzz.ratio(rom_one, rom_two)

        if ratio > threshold_rom:
            return True
        
    return False

def data_matching(item_one, item_two, threshold_name, threshold_ram, threshold_rom):
    brand_checked = brand_matching(item_one, item_two)
    if not brand_checked:
        return False
        
    name_checked = name_matching(item_one, item_two, threshold_name)
    if not name_checked:
        return False
    
    ram_checked = ram_matching(item_one, item_two, threshold_ram)
    if not ram_checked:
        return False

    rom_checked = rom_matching(item_one, item_two, threshold_rom)
    if not rom_checked:
        return False
    
    return True

# %%
#True Positive
def true_positive(ground_truth, prediction):
    tp = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 1 and pred == 1:
            tp +=1
    return tp

#True Negative
def true_negative(ground_truth, prediction):
    tn = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 0 and pred == 0:
            tn +=1
    return tn

#False Positive
def false_positive(ground_truth, prediction):
    fp = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 0 and pred == 1:
            fp +=1
    return fp

#False Negative
def false_negative(ground_truth, prediction):
    fn = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 1 and pred == 0:
            fn +=1
    return fn

def accuracy(ground_truth, prediction):
    tp = true_positive(ground_truth, prediction)  
    fp = false_positive(ground_truth, prediction)  
    fn = false_negative(ground_truth, prediction)  
    tn = true_negative(ground_truth, prediction)  
    acc_score = (tp + tn)/ (tp + tn + fp + fn)  
    return acc_score

def precision_positive(ground_truth, prediction):
    tp = true_positive(ground_truth, prediction)  
    fp = false_positive(ground_truth, prediction)  
    prec = tp/ (tp + fp)  
    return prec

def precision_negative(ground_truth, prediction):
    tn = true_negative(ground_truth, prediction)  
    fn = false_negative(ground_truth, prediction)  
    prec = tn / (tn + fn)  
    return prec

def recall_positive(ground_truth, prediction):
    tp = true_positive(ground_truth, prediction)  
    fn = false_negative(ground_truth, prediction)  
    rec = tp/ (tp + fn)  
    return rec

def recall_negative(ground_truth, prediction):
    tn = true_negative(ground_truth, prediction) 
    fp = false_positive(ground_truth, prediction)  
    rec = tn/ (tn + fp)  
    return rec

def f1_positive(ground_truth, prediction):
    p = precision_positive(ground_truth, prediction)
    r = recall_positive(ground_truth, prediction)
    f1_score_positive = 2 * p * r/ (p + r) 
    return f1_score_positive

def f1_negative(ground_truth, prediction):
    p = precision_negative(ground_truth, prediction)
    r = recall_negative(ground_truth, prediction)
    f1_score_negative = 2 * p * r/ (p + r) 
    return f1_score_negative

# %%
# clean 
import json
with open('data_first_final.json', encoding='utf-8') as f:
    data_first_final = json.load(f)

with open('data_second_final.json', encoding='utf-8') as f:
    data_second_final = json.load(f)

with open('label_final.json', encoding='utf-8') as f:
    label_final = json.load(f)

label_predict = []
for i in range(len(data_first_final)):
   
    clean_data(data_first_final[i])
    clean_data(data_second_final[i])
  
    if data_matching(data_first_final[i], data_second_final[i], threshold_name=90, threshold_ram=99, threshold_rom=99):
        label_predict.append(1)
    else:
        label_predict.append(0)
    
print("                 1            |         0    ")
print("precision:", precision_positive(label_final, label_predict), "|", precision_negative(label_final, label_predict))
print("recall   :", recall_positive(label_final, label_predict), "|",  recall_negative(label_final, label_predict))
print("f1_score :", f1_positive(label_final, label_predict), "|", f1_negative(label_final, label_predict))
# Out:
#                  1            |         0
# precision: 0.6065573770491803 | 0.9899497487437185
# recall   : 0.9736842105263158 | 0.8040816326530612
# f1_score : 0.7474747474747474 | 0.8873873873873873

# %%
# khong clean
import json
with open('data_first_final.json', encoding='utf-8') as f:
    data_first_final = json.load(f)

with open('data_second_final.json', encoding='utf-8') as f:
    data_second_final = json.load(f)

with open('label_final.json', encoding='utf-8') as f:
    label_final = json.load(f)

label_predict = []
for i in range(len(data_first_final)):
  
    if data_matching(data_first_final[i], data_second_final[i], threshold_name=90, threshold_ram=99, threshold_rom=99):
        label_predict.append(1)
    else:
        label_predict.append(0)

print("                 1            |         0    ")
print("precision:", precision_positive(label_final, label_predict), "|", precision_negative(label_final, label_predict))
print("recall   :", recall_positive(label_final, label_predict), "|",  recall_negative(label_final, label_predict))
print("f1_score :", f1_positive(label_final, label_predict), "|", f1_negative(label_final, label_predict))
# Out:
#                  1            |         0
# precision: 0.3829787234042553 | 0.7883211678832117
# recall   : 0.23684210526315788 | 0.8816326530612245
# f1_score : 0.2926829268292683 | 0.8323699421965318

# %% [markdown]
# # ROM

# %%
import re
not_in_keys = 0
empty_string = 0
for i in range(len(list_name_not_rom)):

        name = list_name_not_rom[i].lower()
        
        check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
        if check_have_ram_rom:
            ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]
                 
            if '-' in ram_rom:
                rom = re.split('[-]', ram_rom)[-1]
            elif '|' in ram_rom:
                rom = re.split('[|]', ram_rom)[-1]
                
            elif '/' in ram_rom:
                rom = re.split('[/]', ram_rom)[-1]
            else:
                rom = re.split('[\s]', ram_rom)[-1]

            print( rom)
            if check_in_or_not[i] == 1:
                empty_string += 1
            else:
                not_in_keys += 1
        
        else:
            check_have_rom = re.search("[0-9]+[tmg][b]", name)
            if check_have_rom:
                rom = re.findall("[0-9]+[tmg][b]", name)[0]
                 
                print( rom)
                if check_in_or_not[i] == 1:
                    empty_string += 1
                else:
                    not_in_keys += 1
