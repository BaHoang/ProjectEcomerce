# %%
import re

def clean_brand(brand):
  brand = str(brand).strip().split()[0].lower()
  if brand == 'iphone':
    brand = 'apple'
  return brand

def clean_price_discount(priceDiscount, check):
  if check:
    list_word = ["Liên", "hệ"]
    priceDiscount = str(priceDiscount).strip().replace('.', '').replace('đ', '')
    for word in list_word:
      if word in priceDiscount:
          priceDiscount = 0
          break
    return str(priceDiscount)
  else:
    priceDiscount = str(priceDiscount).strip().replace('đ', '').split('.')[0]
    return str(priceDiscount)

def clean_price(price, check):
  if check:
    price = str(price).strip().replace('.', '').replace('đ', '')
  else:
    price = str(price).strip().replace('đ', '').split('.')[0]
  return str(price)

def clean_ram(ram):
  ram = str(ram).strip().upper()
  if 'GB' in ram or 'G' in ram:
    ram = ram.split()[0].replace('G', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "GB"
      return ram
  
  if 'MB' in ram or 'M' in ram:
    ram = ram.split()[0].replace('M', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "MB"
      return ram

  return ""

def preprocessing_ram(item):
  if ("ram" not in item) or ("ram" in item and item["ram"] == None) :
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]

        if '-' in ram_rom:
            ram = re.split('[-]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '|' in ram_rom:
            ram = re.split('[|]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '/' in ram_rom:
            ram = re.split('[/]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        else:
            ram = re.split('[\s]', ram_rom)[0]    
            item["ram"] = clean_ram(ram) 
  
  if "ram" in item:
    item['ram'] = clean_ram(item['ram'])

def clean_rom(rom):
  rom = str(rom).strip().upper()
  if 'GB' in rom or 'G' in rom:
    rom = rom.split()[0].replace('G', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "GB"
      return rom
  
  if 'MB' in rom or 'M' in rom:
    rom = rom.split()[0].replace('M', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "MB"
      return rom
  
  if 'TB' in rom or 'T' in rom:
    rom = rom.split()[0].replace('T', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "TB"
      return rom

  return ""

def preprocessing_rom(item):
  if ("rom" not in item) or ("rom" in item and item["rom"] == None):
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]
        if '-' in ram_rom:
            rom = re.split('[-]', ram_rom)[-1]
            item["rom"] = rom
        elif '|' in ram_rom:
            rom = re.split('[|]', ram_rom)[-1]
            item["rom"] = rom
        elif '/' in ram_rom:
            rom = re.split('[/]', ram_rom)[-1]
            item["rom"] = rom
        else:
            rom = re.split('[\s]', ram_rom)[-1]    
            item["rom"] = rom   
    else:
        check_have_rom = re.search("[0-9]+[tmg][b]", name)
        if check_have_rom:
            rom = re.findall("[0-9]+[tmg][b]", name)[0]
            item["rom"] = rom
  
  if "rom" in item:
    item['rom'] = clean_rom(item['rom'])

def clean_data(item):
  if 'brand' in item.keys():
    item['brand'] = clean_brand(item['brand'])

  preprocessing_ram(item)
  preprocessing_rom(item)
    
  if 'price' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['price'] = clean_price(item['price'], False)
    else:
        item['price'] = clean_price(item['price'], True)

  if 'priceDiscount' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], False)
    else:
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], True)

  if 'cameraSau' in item.keys():
    item['cameraSau'] = str(item['cameraSau']).strip()
  
  if 'cameraTruoc' in item.keys():
    item['cameraTruoc'] = str(item['cameraTruoc']).strip()
  
  if 'chipset' in item.keys():
    item['chipset'] = str(item['chipset']).strip()

  if 'color' in item.keys():
    item['color'] = str(item['color']).strip()
  
  if 'image' in item.keys():
    item['image'] = str(item['image']).strip()
  
  if 'linkProduct' in item.keys():
    item['linkProduct'] = str(item['linkProduct']).strip()
  
  if 'manHinh' in item.keys():
    item['manHinh'] = str(item['manHinh']).strip()

  if 'name' in item.keys():
    item['name'] = str(item['name']).strip()
  
  if 'operating' in item.keys():
    item['operating'] = str(item['operating']).strip()
  
  if 'pin' in item.keys():
    item['pin'] = str(item['pin']).strip()

# %%
#True Positive
def true_positive(ground_truth, prediction):
    tp = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 1 and pred == 1:
            tp +=1
    return tp

#True Negative
def true_negative(ground_truth, prediction):
    tn = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 0 and pred == 0:
            tn +=1
    return tn

#False Positive
def false_positive(ground_truth, prediction):
    fp = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 0 and pred == 1:
            fp +=1
    return fp

#False Negative
def false_negative(ground_truth, prediction):
    fn = 0
    for gt, pred in zip(ground_truth, prediction):
        if gt == 1 and pred == 0:
            fn +=1
    return fn

def accuracy(ground_truth, prediction):
    tp = true_positive(ground_truth, prediction)  
    fp = false_positive(ground_truth, prediction)  
    fn = false_negative(ground_truth, prediction)  
    tn = true_negative(ground_truth, prediction)  
    acc_score = (tp + tn)/ (tp + tn + fp + fn)  
    return acc_score

def precision_positive(ground_truth, prediction):
    tp = true_positive(ground_truth, prediction)  
    fp = false_positive(ground_truth, prediction)  
    prec = tp/ (tp + fp)  
    return prec

# def precision_negative(ground_truth, prediction):
#     tn = true_negative(ground_truth, prediction)  
#     fn = false_negative(ground_truth, prediction)  
#     prec = tn / (tn + fn)  
#     return prec

def recall_positive(ground_truth, prediction):
    tp = true_positive(ground_truth, prediction)  
    fn = false_negative(ground_truth, prediction)  
    rec = tp/ (tp + fn)  
    return rec

# def recall_negative(ground_truth, prediction):
#     tn = true_negative(ground_truth, prediction) 
#     fp = false_positive(ground_truth, prediction)  
#     rec = tn/ (tn + fp)  
#     return rec

def f1_positive(ground_truth, prediction):
    p = precision_positive(ground_truth, prediction)
    r = recall_positive(ground_truth, prediction)
    f1_score_positive = 2 * p * r/ (p + r) 
    return f1_score_positive

# def f1_negative(ground_truth, prediction):
#     p = precision_negative(ground_truth, prediction)
#     r = recall_negative(ground_truth, prediction)
#     f1_score_negative = 2 * p * r/ (p + r) 
#     return f1_score_negative

# %% [markdown]
# # Khong them color

# %%
from fuzzywuzzy import fuzz
import re

def brand_matching (item_one, item_two):
    if "brand" in item_one.keys() and "brand" in item_two.keys():
        brand_one = item_one["brand"]
        brand_two = item_two["brand"]
        if brand_one == brand_two:
            return True
        list_same = ['xiaomi', 'poco', 'redmi']
        if brand_one in list_same and brand_two in list_same:
            return True
    return False

list_color = ['huyền', 'cam', 'đen', 'xanh', 'tím', 'xám', 'ánh', 'kim', 'đồng', 'thiên', 'thạch', 'dương', 'đậm', 'thanh', 'vàng', 'bạc', 'trắng', 'hồng', 'hà', 'lá', 'đỏ', 'kem', 'lục', 'nhạt', 'biển', 'cực', 'quang']
list_brand = ['masstel','itel','nubia', 'tcl', 'vsmart', 'oneplus', 'asus', 'bphone', 'philips', 'samsung', 'galaxy', 'xiaomi', 'apple', 'iphone', 'oppo', 'realme', 'nokia', 'vivo', 'tecno']
list_delete = ["dộng", "box", "chính", "hãng", "vna", "vn/a", "trưng", "bày", "cũ", "gia", "studio", "màu", "mới", "chính", "hãng", "ll", "za", "chính", "hãng"]
def clean_name(name):
    name = name.lower()
    name = name.replace("điện", "").replace("thoại", "")
    name = re.sub("\(.*\)", "", name)
    name = name.split("-")[0]
    name = name.split("–")[0]
    name = name.split("|")[0]
    name = re.sub("\d+[tmg]b(.*\d+[tmg]b)?", "", name)

    for item_delete in list_delete:
        name = name.replace(item_delete, "")
        
    for brand in list_brand:
        name = name.replace(brand, "")
    for color in list_color:
        name = name.replace(color, "")

    # khoang cach giua 2 tu chi la 1 whitespace    
    name = name.split()
    name = ' '.join(name)
    return name

def name_matching (item_one, item_two, threshold):
    if "name" in item_one.keys() and "name" in item_two.keys():
        name_one = item_one["name"]
        name_two = item_two["name"]
        name_one_new = clean_name(name_one)
        name_two_new = clean_name(name_two)

        ratio = fuzz.token_set_ratio(name_one_new, name_two_new)
        # ratio = fuzz.ratio(name_one_new, name_two_new)
        
        if ratio >= threshold:
            return True
            
    return False

def ram_matching (item_one, item_two, threshold_ram):

    if "ram" in item_one.keys() and "ram" in item_two.keys():
        ram_one = item_one["ram"]
        ram_two = item_two["ram"]
        ratio = fuzz.ratio(ram_one, ram_two)

        if ratio >= threshold_ram:
            return True
        
    return False

def rom_matching (item_one, item_two, threshold_rom):

    if "rom" in item_one.keys() and "rom" in item_two.keys():
        rom_one = item_one["rom"]
        rom_two = item_two["rom"]
        ratio = fuzz.ratio(rom_one, rom_two)

        if ratio >= threshold_rom:
            return True
        
    return False

def data_matching(item_one, item_two, threshold_name, threshold_ram, threshold_rom):
    brand_checked = brand_matching(item_one, item_two)
    if not brand_checked:
        return False
        
    name_checked = name_matching(item_one, item_two, threshold_name)
    if not name_checked:
        return False
    
    ram_checked = ram_matching(item_one, item_two, threshold_ram)
    if not ram_checked:
        return False

    rom_checked = rom_matching(item_one, item_two, threshold_rom)
    if not rom_checked:
        return False
    
    return True

# %%
# 0 clean 
import json
list_threshold_name = [75, 85, 95]
list_threshold_ram = [80, 90]
list_threshold_rom = [80, 90]

def test(list_threshold_name, list_threshold_ram, list_threshold_rom):

    with open('data_first_final.json', encoding='utf-8') as f:
        data_first_final = json.load(f)

    with open('data_second_final.json', encoding='utf-8') as f:
        data_second_final = json.load(f)

    with open('label_final.json', encoding='utf-8') as f:
        label_final = json.load(f)

    for i in range(len(data_first_final)):
        clean_data(data_first_final[i])
        clean_data(data_second_final[i])
    print("                  precision       recall              f1")
    for threshold_name in list_threshold_name:
        for threshold_ram in list_threshold_ram:
            for threshold_rom in list_threshold_rom:
                label_predict = []
                for i in range(len(data_first_final)):

                    if data_matching(data_first_final[i], data_second_final[i], threshold_name, threshold_ram, threshold_rom):
                        label_predict.append(1)
                    else:
                        label_predict.append(0)
                        
                print(threshold_name, threshold_ram, threshold_rom, precision_positive(label_final, label_predict), recall_positive(label_final, label_predict), f1_positive(label_final, label_predict) )
                
            

test(list_threshold_name, list_threshold_ram, list_threshold_rom)
# Out:
#                   precision       recall              f1
# 75 80 80 0.6016260162601627 0.9736842105263158 0.7437185929648242
# 75 80 90 0.6065573770491803 0.9736842105263158 0.7474747474747474
# 75 90 80 0.6016260162601627 0.9736842105263158 0.7437185929648242
# 75 90 90 0.6065573770491803 0.9736842105263158 0.7474747474747474
# 85 80 80 0.6016260162601627 0.9736842105263158 0.7437185929648242
# 85 80 90 0.6065573770491803 0.9736842105263158 0.7474747474747474
# 85 90 80 0.6016260162601627 0.9736842105263158 0.7437185929648242
# 85 90 90 0.6065573770491803 0.9736842105263158 0.7474747474747474
# 95 80 80 0.6434782608695652 0.9736842105263158 0.7748691099476439
# 95 80 90 0.6491228070175439 0.9736842105263158 0.7789473684210527
# 95 90 80 0.6434782608695652 0.9736842105263158 0.7748691099476439
# 95 90 90 0.6491228070175439 0.9736842105263158 0.7789473684210527

# %%
# 0 clean 
import json
list_threshold_name = [75, 85, 95]
list_threshold_ram = [80, 90]
list_threshold_rom = [80, 90]

def test(list_threshold_name, list_threshold_ram, list_threshold_rom):

    with open('data_first_final.json', encoding='utf-8') as f:
        data_first_final = json.load(f)

    with open('data_second_final.json', encoding='utf-8') as f:
        data_second_final = json.load(f)

    with open('label_final.json', encoding='utf-8') as f:
        label_final = json.load(f)

    # for i in range(len(data_first_final)):
    #     clean_data(data_first_final[i])
    #     clean_data(data_second_final[i])
    print("                  precision       recall              f1")
    for threshold_name in list_threshold_name:
        for threshold_ram in list_threshold_ram:
            for threshold_rom in list_threshold_rom:
                label_predict = []
                for i in range(len(data_first_final)):

                    if data_matching(data_first_final[i], data_second_final[i], threshold_name, threshold_ram, threshold_rom):
                        label_predict.append(1)
                    else:
                        label_predict.append(0)
                        
                print(threshold_name, threshold_ram, threshold_rom, precision_positive(label_final, label_predict), recall_positive(label_final, label_predict), f1_positive(label_final, label_predict) )
                
            

test(list_threshold_name, list_threshold_ram, list_threshold_rom)
# Out:
#                   precision       recall              f1
# 75 80 80 0.453125 0.3815789473684211 0.4142857142857143
# 75 80 90 0.4603174603174603 0.3815789473684211 0.4172661870503597
# 75 90 80 0.39215686274509803 0.2631578947368421 0.31496062992125984
# 75 90 90 0.4 0.2631578947368421 0.3174603174603174
# 85 80 80 0.453125 0.3815789473684211 0.4142857142857143
# 85 80 90 0.4603174603174603 0.3815789473684211 0.4172661870503597
# 85 90 80 0.39215686274509803 0.2631578947368421 0.31496062992125984
# 85 90 90 0.4 0.2631578947368421 0.3174603174603174
# 95 80 80 0.4915254237288136 0.3815789473684211 0.4296296296296297
# 95 80 90 0.5 0.3815789473684211 0.4328358208955224
# 95 90 80 0.425531914893617 0.2631578947368421 0.3252032520325203
# 95 90 90 0.43478260869565216 0.2631578947368421 0.32786885245901637

# %%
# clean 
import json
with open('data_first_final.json', encoding='utf-8') as f:
    data_first_final = json.load(f)

with open('data_second_final.json', encoding='utf-8') as f:
    data_second_final = json.load(f)

with open('label_final.json', encoding='utf-8') as f:
    label_final = json.load(f)

label_predict = []
for i in range(len(data_first_final)):
   
    clean_data(data_first_final[i])
    clean_data(data_second_final[i])
  
    if data_matching(data_first_final[i], data_second_final[i], threshold_name=90, threshold_ram=100, threshold_rom=100):
        label_predict.append(1)
    else:
        label_predict.append(0)
    
print("                 1            ")
print("precision:", precision_positive(label_final, label_predict))
print("recall   :", recall_positive(label_final, label_predict))
print("f1_score :", f1_positive(label_final, label_predict))
# Out:
#                  1
# precision: 0.6065573770491803
# recall   : 0.9736842105263158
# f1_score : 0.7474747474747474

# %%
# khong clean
import json
with open('data_first_final.json', encoding='utf-8') as f:
    data_first_final = json.load(f)

with open('data_second_final.json', encoding='utf-8') as f:
    data_second_final = json.load(f)

with open('label_final.json', encoding='utf-8') as f:
    label_final = json.load(f)

label_predict = []
for i in range(len(data_first_final)):
  
    if data_matching(data_first_final[i], data_second_final[i], threshold_name=90, threshold_ram=99, threshold_rom=99):
        label_predict.append(1)
    else:
        label_predict.append(0)

print("                 1            ")
print("precision:", precision_positive(label_final, label_predict))
print("recall   :", recall_positive(label_final, label_predict))
print("f1_score :", f1_positive(label_final, label_predict))
# Out:
#                  1
# precision: 0.3829787234042553
# recall   : 0.23684210526315788
# f1_score : 0.2926829268292683

# %% [markdown]
# # Them thuoc tinh color

# %%
color_cluster = [['đen ghi',
  'phantom black',
  'đen',
  'đen huyền bí',
  'đen tinh vân',
  'đen fs',
  'đen (trôi bh)',
  'đen phá cách',
  'màu đen fs',
  'màu đen',
  'space black',
  'midnight',
  'black',
  'matte black',
  'đen bí ẩn',
  'đen tuyền',
  'đen thiên thạch',
  'đen mạnh mẽ',
  'graphite',
  'đen caro',
  'đen graphite',
  'black - red',
  'đen từ tính',
  'cosmic black',
  'obsidian',
  'đen kim sa',
  'tech black',
  'đen tuyền',
  'đen tinh quang',
  'graphite black',
  'aura black',
  'đen nhám'],
 ['trắng ngọc',
  'trắng',
  'phantom white',
  'white',
  'starlight',
  'trắng cực quang',
  'trắng ngọc trai',
  'trắng kim cương',
  'trắng flora',
  'aura white'],
 ['tím',
  'deep purple',
  'purple',
  'tím hồng',
  'tím pastel',
  'tím cực quang',
  'violet',
  'lavender'],
 ['xám', 'gray', 'xám ánh kim', 'xám kim loại', 'space grey', 'grey'],
 ['cam đào', 'cam', 'orange'],
 ['bạc', 'silver', 'artic silver'],
 ['vàng',
  'gold',
  'pink gold',
  'yellow',
  'vàng (gold)',
  'vàng đồng',
  'vàng phù sa',
  'vàng hồng',
  'prime gold',
  'supernova',
  'rose gold'],
 ['burgundy', 'đỏ', 'red', 'aura red'],
 ['đồng ánh hồng', 'đồng', 'cooper'],
 ['pink', 'hồng'],
 ['kem', 'moon beige', 'beige', 'cream'],
 ['green',
  'gray green',
  'alpine green',
  'light green',
  'midnight green',
  'mystic green',
  'xanh lá',
  'xanh mint',
  'xanh lục',
  'xanh thiên thạch',
  'xanh vàng',
  'xanh niken',
  'xanh olive',
  'băng cẩm thạch',
  'xanh trắng'],
 ['xanh tím',
  'lam',
  'blue',
  'dương',
  'xanh đen',
  'xanh biển',
  'xanh thiên thanh',
  'xanh nhạt',
  'navy',
  'xanh tinh vân',
  'xanh ánh kim',
  'xanh thiên hà',
  'xanh bắc âu'],
 ['xanh đen'],
 ['xanh hồng'],
 ['xanh caro']]

# %%
def get_index_in_cluster(color):
    for i in range(len(color_cluster)):
        if color.lower().strip() in color_cluster[i]:
            return i
    return -1

# %%
from fuzzywuzzy import fuzz
import re

def brand_matching (item_one, item_two):
    if "brand" in item_one.keys() and "brand" in item_two.keys():
        brand_one = item_one["brand"]
        brand_two = item_two["brand"]
        if brand_one == brand_two:
            return True
        list_same = ['xiaomi', 'poco', 'redmi']
        if brand_one in list_same and brand_two in list_same:
            return True
    return False

list_color = ['huyền', 'cam', 'đen', 'xanh', 'tím', 'xám', 'ánh', 'kim', 'đồng', 'thiên', 'thạch', 'dương', 'đậm', 'thanh', 'vàng', 'bạc', 'trắng', 'hồng', 'hà', 'lá', 'đỏ', 'kem', 'lục', 'nhạt', 'biển', 'cực', 'quang']
list_brand = ['masstel','itel','nubia', 'tcl', 'vsmart', 'oneplus', 'asus', 'bphone', 'philips', 'samsung', 'galaxy', 'xiaomi', 'apple', 'iphone', 'oppo', 'realme', 'nokia', 'vivo', 'tecno']
list_delete = ["dộng", "box", "chính", "hãng", "vna", "vn/a", "trưng", "bày", "cũ", "gia", "studio", "màu", "mới", "chính", "hãng", "ll", "za", "chính", "hãng"]
def clean_name(name):
    name = name.lower()
    name = name.replace("điện", "").replace("thoại", "")
    name = re.sub("\(.*\)", "", name)
    name = name.split("-")[0]
    name = name.split("–")[0]
    name = name.split("|")[0]
    name = re.sub("\d+[tmg]b(.*\d+[tmg]b)?", "", name)

    for item_delete in list_delete:
        name = name.replace(item_delete, "")
        
    for brand in list_brand:
        name = name.replace(brand, "")
    for color in list_color:
        name = name.replace(color, "")

    # khoang cach giua 2 tu chi la 1 whitespace    
    name = name.split()
    name = ' '.join(name)
    return name

def name_matching (item_one, item_two, threshold):
    if "name" in item_one.keys() and "name" in item_two.keys():
        name_one = item_one["name"]
        name_two = item_two["name"]
        name_one_new = clean_name(name_one)
        name_two_new = clean_name(name_two)

        ratio = fuzz.token_set_ratio(name_one_new, name_two_new)
        # ratio = fuzz.ratio(name_one_new, name_two_new)
        if ratio >= threshold:
            return True     
    return False

def ram_matching (item_one, item_two, threshold_ram):
    if "ram" in item_one.keys() and "ram" in item_two.keys():
        ram_one = item_one["ram"]
        ram_two = item_two["ram"]
        ratio = fuzz.ratio(ram_one, ram_two)
        if ratio >= threshold_ram:
            return True
    return False

def rom_matching (item_one, item_two, threshold_rom):
    if "rom" in item_one.keys() and "rom" in item_two.keys():
        rom_one = item_one["rom"]
        rom_two = item_two["rom"]
        ratio = fuzz.ratio(rom_one, rom_two)
        if ratio >= threshold_rom:
            return True
    return False

def color_matching (item_one, item_two):
    if "color" in item_one.keys() and "color" in item_two.keys():
        color_one = item_one["color"]
        color_two = item_two["color"]
        # ratio = fuzz.ratio(color_one, color_two)
        index_color_one = get_index_in_cluster(color_one)
        index_color_two = get_index_in_cluster(color_two)

        if index_color_one > -1 and index_color_one == index_color_two :
            return True
        
    return False

def data_matching(item_one, item_two, threshold_name, threshold_ram, threshold_rom):
    brand_checked = brand_matching(item_one, item_two)
    if not brand_checked:
        return False
        
    name_checked = name_matching(item_one, item_two, threshold_name)
    if not name_checked:
        return False
    
    ram_checked = ram_matching(item_one, item_two, threshold_ram)
    if not ram_checked:
        return False

    rom_checked = rom_matching(item_one, item_two, threshold_rom)
    if not rom_checked:
        return False
    
    color_checked = color_matching(item_one, item_two)
    if not color_checked:
        return False
    
    return True

# %%
# clean 
import json
list_threshold_name = [75, 85, 95]
list_threshold_ram = [80, 90]
list_threshold_rom = [80, 90]

def test(list_threshold_name, list_threshold_ram, list_threshold_rom):

    with open('data_first_final.json', encoding='utf-8') as f:
        data_first_final = json.load(f)

    with open('data_second_final.json', encoding='utf-8') as f:
        data_second_final = json.load(f)

    with open('label_final.json', encoding='utf-8') as f:
        label_final = json.load(f)

    for i in range(len(data_first_final)):
        clean_data(data_first_final[i])
        clean_data(data_second_final[i])
    print("                  precision       recall              f1")
    for threshold_name in list_threshold_name:
        for threshold_ram in list_threshold_ram:
            for threshold_rom in list_threshold_rom:
                label_predict = []
                for i in range(len(data_first_final)):

                    if data_matching(data_first_final[i], data_second_final[i], threshold_name, threshold_ram, threshold_rom):
                        label_predict.append(1)
                    else:
                        label_predict.append(0)
                        
                print(threshold_name, threshold_ram, threshold_rom, precision_positive(label_final, label_predict), recall_positive(label_final, label_predict), f1_positive(label_final, label_predict) )
                
            

test(list_threshold_name, list_threshold_ram, list_threshold_rom)
# Out:
#                   precision       recall              f1
# 75 80 80 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 75 80 90 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 75 90 80 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 75 90 90 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 85 80 80 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 85 80 90 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 85 90 80 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 85 90 90 0.7558139534883721 0.8552631578947368 0.8024691358024691
# 95 80 80 0.7926829268292683 0.8552631578947368 0.8227848101265822
# 95 80 90 0.7926829268292683 0.8552631578947368 0.8227848101265822
# 95 90 80 0.7926829268292683 0.8552631578947368 0.8227848101265822
# 95 90 90 0.7926829268292683 0.8552631578947368 0.8227848101265822

# %%
# 0 clean 
import json
list_threshold_name = [75, 85, 95]
list_threshold_ram = [80,  90]
list_threshold_rom = [80,  90]

def test(list_threshold_name, list_threshold_ram, list_threshold_rom):

    with open('data_first_final.json', encoding='utf-8') as f:
        data_first_final = json.load(f)

    with open('data_second_final.json', encoding='utf-8') as f:
        data_second_final = json.load(f)

    with open('label_final.json', encoding='utf-8') as f:
        label_final = json.load(f)

    # for i in range(len(data_first_final)):
    #     clean_data(data_first_final[i])
    #     clean_data(data_second_final[i])
    print("name ram rom        precision       recall              f1")
    for threshold_name in list_threshold_name:
        for threshold_ram in list_threshold_ram:
            for threshold_rom in list_threshold_rom:
                label_predict = []
                for i in range(len(data_first_final)):

                    if data_matching(data_first_final[i], data_second_final[i], threshold_name, threshold_ram, threshold_rom):
                        label_predict.append(1)
                    else:
                        label_predict.append(0)
                        
                print(threshold_name, threshold_ram, threshold_rom, precision_positive(label_final, label_predict), recall_positive(label_final, label_predict), f1_positive(label_final, label_predict) )
                
            

test(list_threshold_name, list_threshold_ram, list_threshold_rom)
# Out:
# name ram rom        precision       recall              f1
# 75 80 80 0.6341463414634146 0.34210526315789475 0.4444444444444444
# 75 80 90 0.6341463414634146 0.34210526315789475 0.4444444444444444
# 75 90 80 0.5757575757575758 0.25 0.3486238532110092
# 75 90 90 0.5757575757575758 0.25 0.3486238532110092
# 85 80 80 0.6341463414634146 0.34210526315789475 0.4444444444444444
# 85 80 90 0.6341463414634146 0.34210526315789475 0.4444444444444444
# 85 90 80 0.5757575757575758 0.25 0.3486238532110092
# 85 90 90 0.5757575757575758 0.25 0.3486238532110092
# 95 80 80 0.6842105263157895 0.34210526315789475 0.45614035087719296
# 95 80 90 0.6842105263157895 0.34210526315789475 0.45614035087719296
# 95 90 80 0.6129032258064516 0.25 0.35514018691588783
# 95 90 90 0.6129032258064516 0.25 0.35514018691588783

# %%
count = 0
for i in label_final:
    if i == 0:
        count += 1
print(count)
# Out:
# 224

# %%
count = 0
for i in label_predict:
    if i == 1:
        count += 1
print(count)
# Out:
# 82

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db')
phones = db.data_phone_items
list_database = []
for item in list(phones.find()):
    list_database.append(item)

list_all_color = []
 
for item in list_database:
    if item["color"] not in list_all_color:
        list_all_color.append(item["color"])

list_all_color_except_xanh = []
for color in list_all_color:
    tokenize = color.lower().split()
    if 'xanh' not in tokenize and 'blue' not in tokenize and 'green' not in tokenize:
        list_all_color_except_xanh.append(color)

arr_cluster = [['black', 'đen', 'graphite', 'midnight', 'obsidian'],
 ['white', 'trắng', 'starlight'],
 ['tím', 'purple', 'violet', 'lavender'],
 ['xám', 'gray', 'grey'],
 ['cam', 'orange'],
 ['bạc', 'silver'],
 ['vàng', 'gold', 'yellow', 'supernova'],
 ['đỏ', 'red', 'burgundy'],
 ['cooper', 'đồng'],
 ['hồng', 'pink'],
 ['beige', 'kem', 'cream'],]


green_list = ['Green', 'Gray Green', 'Alpine Green', 'Light Green', 'Midnight Green', 'Mystic Green', 'xanh lá', 'Xanh Mint', 'Xanh Lục',  'Xanh Thiên Thạch',  'Xanh vàng', 'Xanh Niken', 'Xanh Olive', 'Băng Cẩm Thạch', 'Xanh Trắng'] 
blue_list = ['xanh tím', 'lam', 'blue', 'dương', 'Xanh đen',  'Xanh Biển', 'Xanh biển',  'Xanh thiên thanh', 'Xanh nhạt', 'Navy', 'Xanh Tinh Vân', 'Xanh ánh kim', 'Xanh Thiên Hà', 'Xanh Bắc Âu'] 
xanh_den_list = ['xanh đen']
xanh_hong_list = [' Xanh Hồng']
xanh_caro_list =   ['Xanh Caro']
list_color_same = []

check_color_classify = []
for i in range(len(list_all_color_except_xanh)):
    check_color_classify.append(False)

for i in range(len(arr_cluster)):
    temp = []
    for j in range(len(list_all_color_except_xanh)):
        if check_color_classify[j] == False:
            color = list_all_color_except_xanh[j]
            tokenize = color.split()
            for word in tokenize:
                if word.lower().strip() in arr_cluster[i] :
                    temp.append(color)
                    check_color_classify[j] = True
                    break
    list_color_same.append(temp)

list_color_same.append(green_list)
list_color_same.append(blue_list)
list_color_same.append(xanh_den_list)
list_color_same.append(xanh_hong_list)
list_color_same.append(xanh_caro_list)

# %%
color_cluster = []
for list_color in list_color_same:
    temp = []
    for color in list_color:
        if color.lower().strip() not in temp:
            temp.append(color.lower().strip())
    color_cluster.append(temp)

# %%
color_cluster

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db')
phones = db.data_phone_items
list_database = []
for item in list(phones.find()):
    list_database.append(item)

# %%
list_namePage = []
for item in list_database:
    if item["namePage"] not in list_namePage:
        list_namePage.append(item["namePage"])

# %%
list_namePage
# Out:
# ['Di Động Thông Minh',
#  'HNamMobile',
#  'Di Động Việt',
#  'Nguyễn Kim',
#  'HoangHaMobile',
#  'ClickBuy',
#  'CellphoneS']

# %%
for namePage in list_namePage:
    count = 0
    for item in list_database:
        if item["namePage"] == namePage:
            count += 1
    print("namePage: ",namePage , ":", count)
# Out:
# namePage:  Di Động Thông Minh : 106
# namePage:  HNamMobile : 201
# namePage:  Di Động Việt : 210
# namePage:  Nguyễn Kim : 201
# namePage:  HoangHaMobile : 466
# namePage:  ClickBuy : 455
# namePage:  CellphoneS : 367

# %%
print(106 + 201 + 210 + 201 + 466 + 455 + 367)
# Out:
# 2006

# %%
len(list_database)
# Out:
# 2006

# %%
for item in list_database:
    print(item['color'])
# Out:
# Trắng Ngọc
# Xanh Mint
# Xanh
# Green
# Xanh
# Đen Ghi
# Trắng
# Phantom Black
# Xám
# Xám
# Tím
# Trắng
# Xám
# Xám
# Burgundy
# Trắng
# Tím
# Đen
# Trắng
# Phantom White
# Xanh Dương
# Xanh Dương
# Trắng
# Vàng
# Xanh
# Đen Huyền Bí
# Đen Ghi
# Đen
# Đen
# Xám
# Đồng ánh hồng
# Đen
# Bạc
# Cam Đào
# Trắng Ngọc
# Cam đào
# Cam
# Xanh
# Đen tinh vân
# Xanh Dương
# Cam Đào
# Xanh
# Xanh
# Xanh dương xỉ
# Đen FS
# Xanh Dương
# Xám
# Đen
# Đen
# Bạc
# Xanh
# Đen
# Đen
# Xanh Dương FS
# Xanh Lá
# Xanh Lá
# Xanh
# Xanh Mint
# Vàng
# Xám
# Xanh Dương
# Trắng
# Xanh
# Xanh
# Xám
# Đen
# Đen
# Bạc
# Trắng
# Đen
# Xanh Nhạt
# xanh
# Đồng
# Đen
# Xanh Biển
# Xanh
# Bạc
# Đen (Trôi BH)
# Đen
# Đen
# Đen
# Đen
# Xanh Lục
# Xanh
# Bạc
# Xanh Lam
# Xám
# Xanh Nhạt
# Xanh Biển
# Đen
# xanh
# Xám
# Xanh
# Xanh
# Kem
# Xanh
# Đen
# Xanh
# Đen
# Xanh Tinh Vân
# Đen Phá Cách
# Màu Đen FS
# Màu đen
# Xanh
# Đen
# Đỏ
# Gold
# Space Black
# Space Black
# Gold
# Deep Purple
# Gold
# Space Black
# Deep Purple
# Deep Purple
# Gray Green
# Phantom Black
# Moon Beige
# Gray Green
# Phantom Black
# Moon Beige
# Gray Green
# Deep Purple
# Gray Green
# Phantom Black
# Moon Beige
# Gold
# Deep Purple
#  Trắng
#  Xanh dương
#  Vàng đồng
#  Xanh dương
#  Đỏ
#  Đen
#  Trắng
#  Xanh dương
#  Đen
#  Xám
#  Đỏ
#  Xám
#  Bạc
#  Bạc
#  Hồng
#  Bạc
#  Bạc
#  Xanh dương
#  Đen
#  Đỏ
#  Đỏ
#  Trắng
#  Tím
#  Tím
#  Đen
#  Bạc
#  Xanh dương
#  Đỏ
#  Bạc
#  Tím
#  Trắng
#  Xanh lá
#  Đen
#  Bạc
#  Vàng
#  Trắng
#  Đen
#  Đỏ
#  Vàng
#  Vàng
#  Đỏ
#  Vàng
#  Trắng
#  Xanh lá
#  Xanh dương
# Xanh lá
# Xanh blue
# Xanh Dương Đậm
# Vàng
# Xanh
# Pink
# Xanh Nhạt
# Pink
# Đen
# Trắng
# Green
# Green
# Pink
# Pink
# Green
# Xanh Niken
# Đen
# Green
# Xanh lá
# Xám
# Phantom Black
# Phantom Black
# Green
# Green
# Phantom Black
# Hồng
# Phantom Black
# Phantom White
# Phantom White
# Phantom Black
# Phantom Black
# Phantom White
# Xanh
# Phantom White
# Burgudy
# Phantom White
# Phantom White
# Burgudy
# Green
# Phantom Black
# Space Black
# Red
# Red
# Silver
# Phantom White
# Silver
# Blue
# Blue
# Gold
# Burgudy
# Silver
# Silver
# Xám
# Gold
# Pink
# Pink
# Space Black
# Gold
# Gold
# Xanh Dương Đậm
# Deep Purple
# Trắng
# Blue
# Xanh Thời Thượng
# Trắng
# Trắng
# Green
# Green
# Deep Purple
# Space Black
# Space Black
# Xanh Nhạt
# Xanh dương
# Red
# Đen mạnh mẽ
# Xanh dương
# Xám
# Starlight
# Starlight
# Deep Purple
# Deep Purple
# Xám
# Pink
# Xám
# Xanh Dương Đậm
# Midnight
# Midnight
# Starlight
# Midnight
# Silver
# Silver
# Silver
# Gold
# Graphite
# Gold
# Space Black
# Gold
# Space Black
# Deep Purple
# Gold
# Silver
# Silver
# Silver
# Đen mạnh mẽ
# Sierra Blue
# Deep Purple
# Space Black
# Gold
# Gold
# Gold
# Xanh thời trang
# Alpine Green
# Deep Purple
# Sierra Blue
# Space Black
# Sierra Blue
# Xanh đam mê
# Đen
# Silver
# Blue
# Bạc
# Graphite
# Deep Purple
# Graphite
# Bạc
# Red
# Đen mạnh mẽ
# Purple
# Starlight
# Blue
# Red
# Midnight
# Black
# Blue
# Vàng phù sa
# Red
# Blue
# Blue
# Red
# Xanh thiên thạch
# Purple
# Purple
# White
# Purple
# Starlight
# Black
# Black
# Red
# Starlight
# Starlight
# Midnight
# Silver
# Purple
# Blue
# Midnight
# Midnight
# Purple
# Black
# Tím hồng
# Black
# Starlight
# Blue
# Xanh đen
# Blue
# Midnight
# Đen Caro
# Xanh biển
# Xanh Caro
# Xanh tím
# Black
# Black
# Black
# Blue
# Blue
# Blue
# Đen
# Đen
# White
# Xanh
# Bạc Ánh Xanh
# Đen
# Gray
# Trắng
# Xanh
# Đen Caro
# Xanh huyền bí
# Xanh Caro
# Trắng ngọc trai
# Trắng kim cương
# Xanh ánh kim
# Xanh huyền bí
# Xanh
# Đen
# Xanh dương
# Đen
# Xanh lá
# Vàng
# Hồng
# Trắng
# Tím
# Xanh dương
# Xám
# Xanh dương
# Đen
# Xanh
# Xanh lá
# Cam
# Xanh dương
# Đen
# Vàng
# Xanh hồng
# Đen
# Đen
# Xanh
# Đen
# Đỏ
# Xanh
# Tím
# Xanh dương
# Xanh
# Trắng
# Tím
# Xám
# Xanh lá
# Đen
# Đen
# Trắng
# Xanh
# Đen
# Đen
# Trắng
# Bạc
# Đen
# Xanh lá
# Xám
# Xanh dương
# Xám
# Xanh lá
# Đỏ
# Tím
# Trắng
# Đen
# Đen
# Xám
# Xanh
# Kem
# Xám
# Xanh lá
# Tím
# Xanh
# Đen
# Đen
# Cam
# Xanh dương
# Vàng
# Xanh
# Đen
# Xanh
# Đen
# Kem
# Đen
# Bạc
# Đồng
# Đen
# Xanh
# Xanh dương
# Xanh lá
# Đen
# Xanh
# Trắng
# Vàng
# Đen
# Bạc
# Đen
# Bạc
# Xanh
# Bạc
# Xám
# Vàng
# Xám
# Xanh
# Xanh
# Đen
# Xám
# Vàng
# Bạc
# Đen
# Đen
# Xanh
# Đen
# Xanh
# Xám
# Xanh
# Đen
# Trắng
# Đen
# Bạc
# Xanh Đen
# Xám
# Xanh vàng
# Đen
# Xám
# Đỏ
# Xanh
# Xanh
# Trắng
# Tím
# Vàng
# Bạc
# Xanh
# Tím
# Bạc
# Bạc
# Xanh
# Xanh
# Đen
# Xanh dương
# Vàng
# Xanh
# Đen
# Xanh
# Đen
# Đen
# Xanh
# Đen
# Hồng
# Xanh
# Vàng
# Đen
# Xanh
# Xanh lá
# Đen
# Vàng
# Xanh
# Xanh dương
# Xanh
# Đen
# Đen
# Xanh
# Vàng
# Vàng
# Xanh tím
# Đen
# Đen
# Đen
# Bạc
# Đen
# Xanh
# Xanh
# Vàng
# Xanh
# Đỏ/Trắng
# Xám
# Đen
# Xám
# Vàng
# Xanh
# Đen
# Đen
# Đen
# Đỏ
# Đen
# Tím
# Trắng
# Xanh
# Đen
# Xanh
# Đen/Đỏ
# Xám
# Xanh
# Đen
# Xanh
# Đen
# Xanh
# Xanh
# Đen
# Đen
# Xanh lá
# Tím/Xanh dương
# Đen
# Đen
# Xanh dương
# Vàng
# Xám
# Xanh lá
# Xám
# Đen
# Vàng
# Xanh dương
# Xanh
# Xanh tím
# Xám
# Bạc
# Đỏ
# Trắng
# Xanh
# Đỏ
# Đen
# Đen
# Xanh
# Đen
# Đen
# Xanh
# Xanh
# Đen
# Xám
# Xanh
# Xanh dương
# Đen
# Xanh nhạt
# Bạc
# Xanh
# Đen
# Đen/Xám
# Xanh
# Xanh dương
# Đen nhám
# Đen
# Xanh
# Xanh
# Xanh
# Đen
# Vàng
# Xanh
# Xanh
# Xanh
# Đen
# Xám
# Xanh dương
# Đen
# Xanh
# Xám
# Đỏ
# Đen
# Đen

# %%
client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db_clean')
phones = db.data_phone_items_clean

list_database_clean = []
for item in list(phones.find()):
    list_database_clean.append(item)

# %%
len(list_database_clean)
# Out:
# 1776
