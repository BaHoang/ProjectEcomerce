# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db_clean')
phones = db.data_phone_items_clean

list_database_clean = []
for item in list(phones.find()):
    list_database_clean.append(item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[401], line 7
#       4 phones = db.data_phone_items_clean
#       6 list_database_clean = []
# ----> 7 for item in list(phones.find()):
#       8     list_database_clean.append(item)
#
# TypeError: 'list' object is not callable

# %%
brand_unique = []
for item in list_database_clean:
    if item["brand"] not in brand_unique:
        brand_unique.append(item["brand"])

# %%
brand_unique
## xiaomi gom co poco, redmi

# %%
# samsung
list_xiaomi = []
for item in list_database_clean:
    if item["brand"] == 'xiaomi':
        list_xiaomi.append(item)

# %%
len(list_xiaomi)
# Out:
# 339

# %%
for item in list_xiaomi:
    print(item["name"])

# %%
def brand_matching (brand_one, brand_two):
    if brand_one == brand_two:
        return True
    else:
        return False

brand_matching("samsung", "samsun")
# Out:
# False

# %%
import re

list_color = ['huyền', 'cam', 'đen', 'xanh', 'tím', 'xám', 'ánh', 'kim', 'đồng', 'thiên', 'thạch', 'dương', 'đậm', 'thanh', 'vàng', 'bạc', 'trắng', 'hồng', 'hà', 'lá', 'đỏ', 'kem', 'lục', 'nhạt', 'biển', 'cực', 'quang']
list_brand = ['masstel','itel','nubia', 'tcl', 'vsmart', 'oneplus', 'asus', 'bphone', 'philips', 'samsung', 'galaxy', 'xiaomi', 'apple', 'iphone', 'oppo', 'realme', 'nokia', 'vivo', 'tecno']
list_delete = ["dộng", "box", "chính", "hãng", "vna", "vn/a", "trưng", "bày", "cũ", "gia", "studio", "màu", "mới", "chính", "hãng", "ll", "za", 'bảo', 'hành', 'tháng',
                'ram']
def clean_name(name):
    name = name.lower()
    name = name.replace("điện", "").replace("thoại", "")
    name = re.sub("\(.*\)", "", name)
    name = name.split("-")[0]
    name = name.split("–")[0]
    name = name.split("|")[0]
    name = name.split(",")[0]
    name = re.sub("\d+[tmg]b?(.*\d+[tmg]b?)?", "", name)

    for item_delete in list_delete:
        name = name.replace(item_delete, "")
        
    for brand in list_brand:
        name = name.replace(brand, "")
    for color in list_color:
        name = name.replace(color, "")

    # khoang cach giua 2 tu chi la 1 whitespace    
    name = name.split()
    name = ' '.join(name)
    return name

# ten + mang + ram + rom + mau + chinh + hang + vna

# %%
clean_name('Xiaomi Pad 5 Chính Hãng Màn 11" Ram 6G/128G, Snap 860 - Bảo Hành 18 Tháng')
# Out:
# 'pad 5 màn 11"'

# %%
from fuzzywuzzy import fuzz
def name_matching (name_one, name_two):
    name_one_new = clean_name(name_one)
    name_two_new = clean_name(name_two)
    print(name_one)
    print(name_two)
    print("==================")
    print(name_one_new)
    print(name_two_new)
    print("===============")

    Token_Set_Ratio = fuzz.token_set_ratio(name_one_new, name_two_new)
    print( Token_Set_Ratio)

one = "masstel izi 50 4g - chính hãng"
two = "masstel izi 20 4g - chính hãng"
name_matching(one, two)
# print(list_apple[17], list_apple[18])
# iphone chon nguong 91, chon 4 tu dau sau khi da tien xu ip, xoa di iphone apple
# samsung chon 3 tu dau tien, chon nguong 90 (xoa di tu samsung, galaxy thi cho ket qua tot hon vi khi do chieu dai tong the cua tu se giam di lam cho ket chinh xac nho di cho nen 
# mot thay doi nho trong ten san pham cung anh huong den ket qua)
# xiaomi nguong 90 chon 4 tu dau tien 
# oppo chon 3 tu dau tien sau khi tien xu ly
# realme chon nhieu nhat 3 tu dau tien chi co 1 cai thoi con lai da so 2 tu
# nokia chon nhieu nhat 3 tu, nguong la 90
# vivo 2 tu, nguong 
# tecco 2 tu, nguong 90
# bphone 1 tu thoi nguong 91
# asus da so 3 tu chi co duy nhat 1 cai 4 tu
# onpluc da so 3 tu, lon hon 91
# nubia 4 tu 
# masstel nguong 90
# Out:
# masstel izi 50 4g - chính hãng
# masstel izi 20 4g - chính hãng
# ==================
# izi 50 4g
# izi 20 4g
# ===============
# 89
# /home/hoang/.local/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # RAM
# ## b1 khao sat tat ca du lieu
# ## b2 tu do hinh dung ra cach doi sanh cu th

# %%
ram_unique = []
for item in list_database_clean:
    if "ram" in item.keys() and item["ram"] not in ram_unique:
        ram_unique.append(item["ram"])

# %% [markdown]
# # Khao sat du lieu

# %%
ram_unique
# Out:
# ['8 GB',
#  '6 GB',
#  '4 GB',
#  '2 GB',
#  '',
#  '12 GB',
#  '3 GB',
#  '48 MB',
#  '16 MB',
#  '64 MB',
#  '16 GB']

# %%
count = 0
for item in list_database_clean:
    if "ram" in item.keys():
        
        if item["ram"] != '':
            count += 1

# %%
count
# Out:
# 1751

# %% [markdown]
# # doi sanh ram

# %%
from fuzzywuzzy import fuzz
def ram_matching (ram_one, ram_two):
    ratio = fuzz.ratio(ram_one, ram_two)
    return ratio

ram_matching('12 GB', '12 G')
# Out:
# 89

# %%
for i in range(len(ram_unique)):
    for j in range(len(ram_unique)):
        print(ram_unique[i], "|", ram_unique[j], "|", ram_matching(ram_unique[i], ram_unique[j]))
# Out:
# 8 GB | 8 GB | 100
# 8 GB | 6 GB | 75
# 8 GB | 4 GB | 75
# 8 GB | 2 GB | 75
# 8 GB |  | 0
# 8 GB | 12 GB | 67
# 8 GB | 3 GB | 75
# 8 GB | 48 MB | 67
# 8 GB | 16 MB | 44
# 8 GB | 64 MB | 44
# 8 GB | 16 GB | 67
# 6 GB | 8 GB | 75
# 6 GB | 6 GB | 100
# 6 GB | 4 GB | 75
# 6 GB | 2 GB | 75
# 6 GB |  | 0
# 6 GB | 12 GB | 67
# 6 GB | 3 GB | 75
# 6 GB | 48 MB | 44
# 6 GB | 16 MB | 67
# 6 GB | 64 MB | 67
# 6 GB | 16 GB | 89
# 4 GB | 8 GB | 75
# 4 GB | 6 GB | 75
# 4 GB | 4 GB | 100
# 4 GB | 2 GB | 75
# 4 GB |  | 0
# 4 GB | 12 GB | 67
# 4 GB | 3 GB | 75
# 4 GB | 48 MB | 67
# 4 GB | 16 MB | 44
# 4 GB | 64 MB | 67
# 4 GB | 16 GB | 67
# 2 GB | 8 GB | 75
# 2 GB | 6 GB | 75
# 2 GB | 4 GB | 75
# 2 GB | 2 GB | 100
# 2 GB |  | 0
# 2 GB | 12 GB | 89
# 2 GB | 3 GB | 75
# 2 GB | 48 MB | 44
# 2 GB | 16 MB | 44
# 2 GB | 64 MB | 44
# 2 GB | 16 GB | 67
#  | 8 GB | 0
#  | 6 GB | 0
#  | 4 GB | 0
#  | 2 GB | 0
#  |  | 100
#  | 12 GB | 0
#  | 3 GB | 0
#  | 48 MB | 0
#  | 16 MB | 0
#  | 64 MB | 0
#  | 16 GB | 0
# 12 GB | 8 GB | 67
# 12 GB | 6 GB | 67
# 12 GB | 4 GB | 67
# 12 GB | 2 GB | 89
# 12 GB |  | 0
# 12 GB | 12 GB | 100
# 12 GB | 3 GB | 67
# 12 GB | 48 MB | 40
# 12 GB | 16 MB | 60
# 12 GB | 64 MB | 40
# 12 GB | 16 GB | 80
# 3 GB | 8 GB | 75
# 3 GB | 6 GB | 75
# 3 GB | 4 GB | 75
# 3 GB | 2 GB | 75
# 3 GB |  | 0
# 3 GB | 12 GB | 67
# 3 GB | 3 GB | 100
# 3 GB | 48 MB | 44
# 3 GB | 16 MB | 44
# 3 GB | 64 MB | 44
# 3 GB | 16 GB | 67
# 48 MB | 8 GB | 67
# 48 MB | 6 GB | 44
# 48 MB | 4 GB | 67
# 48 MB | 2 GB | 44
# 48 MB |  | 0
# 48 MB | 12 GB | 40
# 48 MB | 3 GB | 44
# 48 MB | 48 MB | 100
# 48 MB | 16 MB | 60
# 48 MB | 64 MB | 80
# 48 MB | 16 GB | 40
# 16 MB | 8 GB | 44
# 16 MB | 6 GB | 67
# 16 MB | 4 GB | 44
# 16 MB | 2 GB | 44
# 16 MB |  | 0
# 16 MB | 12 GB | 60
# 16 MB | 3 GB | 44
# 16 MB | 48 MB | 60
# 16 MB | 16 MB | 100
# 16 MB | 64 MB | 80
# 16 MB | 16 GB | 80
# 64 MB | 8 GB | 44
# 64 MB | 6 GB | 67
# 64 MB | 4 GB | 67
# 64 MB | 2 GB | 44
# 64 MB |  | 0
# 64 MB | 12 GB | 40
# 64 MB | 3 GB | 44
# 64 MB | 48 MB | 80
# 64 MB | 16 MB | 80
# 64 MB | 64 MB | 100
# 64 MB | 16 GB | 60
# 16 GB | 8 GB | 67
# 16 GB | 6 GB | 89
# 16 GB | 4 GB | 67
# 16 GB | 2 GB | 67
# 16 GB |  | 0
# 16 GB | 12 GB | 80
# 16 GB | 3 GB | 67
# 16 GB | 48 MB | 40
# 16 GB | 16 MB | 80
# 16 GB | 64 MB | 60
# 16 GB | 16 GB | 100

# %% [markdown]
# ### 2 ram giong nhau
# #### chuan hoa du lieu ve dang GB or MB
# #### dat nguong la 100

# %% [markdown]
# # ROM
# ## Khao sat du lieu
# ## Dua ra cach doi sanh cu the

# %% [markdown]
# # Khao sat du lieu

# %%
rom_unique = []
for item in list_database_clean:
    if "rom" in item.keys() and item["rom"] not in rom_unique:
        rom_unique.append(item["rom"])

# %%
rom_unique
# Out:
# ['128 GB',
#  '256 GB',
#  '64 GB',
#  '32 GB',
#  '512 GB',
#  '',
#  '8 GB',
#  '1 TB',
#  '128 MB',
#  '16 GB',
#  '24 MB',
#  '256 MB',
#  '4 GB']

# %%
count = 0
for item in list_database_clean:
    if "rom" in item.keys():        
        if item["rom"] != '':
            count += 1

# %%
count
## co 1920 du lieu rom
# Out:
# 1920

# %% [markdown]
# ## Doi sanh rom

# %%
from fuzzywuzzy import fuzz
def rom_matching (rom_one, rom_two):
    Token_Set_Ratio = fuzz.ratio(rom_one, rom_two)
    return Token_Set_Ratio

rom_matching('128 GB', '28 GB')
# Out:
# 91

# %%
for i in range(len(rom_unique)):
    for j in range(len(rom_unique)):
        print(rom_unique[i], "|", rom_unique[j], "|", rom_matching(rom_unique[i], rom_unique[j]))

# %% [markdown]
# ### 2 rom giong nhau
# #### chuan hoa du lieu ve dang GB or MB
# #### nguong tren 90 la tach duoc thanh 2 loai match voi khong match roi
# #### tat ca cap match deu la 100 ca

# %% [markdown]
# # Check hoan chinh

# %%
def brand_matching (item_one, item_two):
    if "brand" in item_one.keys() and "brand" in item_two.keys():
        brand_one = item_one["brand"]
        brand_two = item_two["brand"]
        if brand_one == brand_two:
            return True
        list_same = ['xiaomi', 'poco', 'redmi']
        if brand_one in list_same and brand_two in list_same:
            return True
        
    return False

brand_matching({"bran": ""}, {"brand":"redmi"})
# Out:
# False

# %%
import re

list_color = ['huyền', 'cam', 'đen', 'xanh', 'tím', 'xám', 'ánh', 'kim', 'đồng', 'thiên', 'thạch', 'dương', 'đậm', 'thanh', 'vàng', 'bạc', 'trắng', 'hồng', 'hà', 'lá', 'đỏ', 'kem', 'lục', 'nhạt', 'biển', 'cực', 'quang']
list_brand = ['masstel','itel','nubia', 'tcl', 'vsmart', 'oneplus', 'asus', 'bphone', 'philips', 'samsung', 'galaxy', 'xiaomi', 'apple', 'iphone', 'oppo', 'realme', 'nokia', 'vivo', 'tecno']
list_delete = ["dộng", "box", "chính", "hãng", "vna", "vn/a", "trưng", "bày", "cũ", "gia", "studio", "màu", "mới", "chính", "hãng", "ll", "za", "chính", "hãng"]
def clean_name(name):
    name = name.lower()
    name = name.replace("điện", "").replace("thoại", "")
    name = re.sub("\(.*\)", "", name)
    name = name.split("-")[0]
    name = name.split("–")[0]
    name = name.split("|")[0]
    name = re.sub("\d+[tmg]b(.*\d+[tmg]b)?", "", name)

    for item_delete in list_delete:
        name = name.replace(item_delete, "")
        
    for brand in list_brand:
        name = name.replace(brand, "")
    for color in list_color:
        name = name.replace(color, "")

    # khoang cach giua 2 tu chi la 1 whitespace    
    name = name.split()
    name = ' '.join(name)
    return name

# ten + mang + ram + rom + mau + chinh + hang + vna

# %%
from fuzzywuzzy import fuzz
def name_matching (item_one, item_two, threshold):
    if "name" in item_one.keys() and "name" in item_two.keys():
        name_one = item_one["name"]
        name_two = item_two["name"]
        name_one_new = clean_name(name_one)
        name_two_new = clean_name(name_two)

        ratio = fuzz.token_set_ratio(name_one_new, name_two_new)
        # ratio = fuzz.ratio(name_one_new, name_two_new)
        
        if ratio > threshold:
            return True
            
    return False

one = "masstel izi 20 4g - chính hãng"
two = "masstel izi 20 4g - chính hãng"
name_matching({"name": one}, {"name": two}, 90)
# Out:
# /home/hoang/.local/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# True

# %%
from fuzzywuzzy import fuzz
def ram_matching (item_one, item_two, threshold_ram):

    if "ram" in item_one.keys() and "ram" in item_two.keys():
        ram_one = item_one["ram"]
        ram_two = item_two["ram"]
        ratio = fuzz.ratio(ram_one, ram_two)

        if ratio > threshold_ram:
            return True
        
    return False

ram_matching({'ram': '12 GB'}, {'ram': '12 GB'}, 99)
# Out:
# True

# %%
from fuzzywuzzy import fuzz
def rom_matching (item_one, item_two, threshold_rom):

    if "rom" in item_one.keys() and "rom" in item_two.keys():
        rom_one = item_one["rom"]
        rom_two = item_two["rom"]
        ratio = fuzz.ratio(rom_one, rom_two)

        if ratio > threshold_rom:
            return True
        
    return False

rom_matching({'rom': '12 GB'}, {'rom': '12 GB'}, 99)
# Out:
# True

# %%
def data_matching(item_one, item_two, threshold_name, threshold_ram, threshold_rom):
    brand_checked = brand_matching(item_one, item_two)
    if not brand_checked:
        return False
        
    name_checked = name_matching(item_one, item_two, threshold_name)
    if not name_checked:
        return False
    
    ram_checked = ram_matching(item_one, item_two, threshold_ram)
    if not ram_checked:
        return False

    rom_checked = rom_matching(item_one, item_two, threshold_rom)
    if not rom_checked:
        return False
    
    return True

# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db_clean')
phones = db.data_phone_items_clean

list_database_clean = []
for item in list(phones.find()):
    list_database_clean.append(item)


item_one = list_database_clean[0]
item_two = list_database_clean[1]
data_matching(item_one, item_two, threshold_name=90, threshold_ram=99, threshold_rom=99)
# Out:
# True

# %%
# cai dat fuzzywuzzy
pip install fuzzywuzzy
# Out:
#   Cell In[57], line 2
#     pip install fuzzywuzzy
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Read data from dababase of ShopTelephone

# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('test')
list_product = db.products

list_product_shop_telephone = []
for item in list(list_product.find()):
    list_product_shop_telephone.append(item)

# %%
import re
import pandas as pd
import numpy

def clean_brand(brand):
  brand = str(brand).strip().split()[0].lower()
  if brand == 'iphone':
    brand = 'apple'
  return brand

def clean_ram(ram):
  ram = str(ram).strip().upper()
  ram = ram + " GB"
  return ram

def clean_rom(rom):
  rom = str(rom).strip().upper()
  rom = rom + " GB"
  return rom

def clean_data(item):
  
  if 'brand' in item.keys():
    item['brand'] = clean_brand(item['brand'])
  
  if 'ram' in item.keys():
    item['ram'] = clean_ram(item['ram'])
  
  if 'rom' in item.keys():
    item['rom'] = clean_rom(item['rom'])

  if 'name' in item.keys():
    item['name'] = str(item['name']).strip()

for item in list_product_shop_telephone:
    clean_data(item)

# %%
for i in range(len(list_product_shop_telephone)):
    for item in list_database_clean:
        if data_matching(list_product_shop_telephone[i], item, threshold_name=90, threshold_ram=99, threshold_rom=99):
            print(i)
            print(item["_id"])

# %% [markdown]
# # Create data test

# %%
import re
from pymongo import MongoClient
client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db')
phones = db.data_phone_items

list_database = []
for item in list(phones.find()):
    list_database.append(item)

def clean_brand(brand):
  brand = str(brand).strip().split()[0].lower()
  if brand == 'iphone':
    brand = 'apple'
  return brand

def clean_price_discount(priceDiscount, check):
  if check:
    list_word = ["Liên", "hệ"]
    priceDiscount = str(priceDiscount).strip().replace('.', '').replace('đ', '')
    for word in list_word:
      if word in priceDiscount:
          priceDiscount = 0
          break
    return str(priceDiscount)
  else:
    priceDiscount = str(priceDiscount).strip().replace('đ', '').split('.')[0]
    return str(priceDiscount)

def clean_price(price, check):
  if check:
    price = str(price).strip().replace('.', '').replace('đ', '')
  else:
    price = str(price).strip().replace('đ', '').split('.')[0]
  return str(price)

def clean_ram(ram):
  ram = str(ram).strip().upper()
  if 'GB' in ram or 'G' in ram:
    ram = ram.split()[0].replace('G', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "GB"
      return ram
  
  if 'MB' in ram or 'M' in ram:
    ram = ram.split()[0].replace('M', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "MB"
      return ram

  return ""

def preprocessing_ram(item):
  if ("ram" not in item) or ("ram" in item and item["ram"] == None) :
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]

        if '-' in ram_rom:
            ram = re.split('[-]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '|' in ram_rom:
            ram = re.split('[|]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '/' in ram_rom:
            ram = re.split('[/]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        else:
            ram = re.split('[\s]', ram_rom)[0]    
            item["ram"] = clean_ram(ram) 
  
  if "ram" in item:
    item['ram'] = clean_ram(item['ram'])

def clean_rom(rom):
  rom = str(rom).strip().upper()
  if 'GB' in rom or 'G' in rom:
    rom = rom.split()[0].replace('G', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "GB"
      return rom
  
  if 'MB' in rom or 'M' in rom:
    rom = rom.split()[0].replace('M', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "MB"
      return rom
  
  if 'TB' in rom or 'T' in rom:
    rom = rom.split()[0].replace('T', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "TB"
      return rom

  return ""

def preprocessing_rom(item):
  if ("rom" not in item) or ("rom" in item and item["rom"] == None):
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]
        if '-' in ram_rom:
            rom = re.split('[-]', ram_rom)[-1]
            item["rom"] = rom
        elif '|' in ram_rom:
            rom = re.split('[|]', ram_rom)[-1]
            item["rom"] = rom
        elif '/' in ram_rom:
            rom = re.split('[/]', ram_rom)[-1]
            item["rom"] = rom
        else:
            rom = re.split('[\s]', ram_rom)[-1]    
            item["rom"] = rom   
    else:
        check_have_rom = re.search("[0-9]+[tmg][b]", name)
        if check_have_rom:
            rom = re.findall("[0-9]+[tmg][b]", name)[0]
            item["rom"] = rom
  
  if "rom" in item:
    item['rom'] = clean_rom(item['rom'])

def clean_data(item):
  
  if 'brand' in item.keys():
    item['brand'] = clean_brand(item['brand'])

  preprocessing_ram(item)
  preprocessing_rom(item)
    
  if 'price' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['price'] = clean_price(item['price'], False)
    else:
        item['price'] = clean_price(item['price'], True)

  if 'priceDiscount' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], False)
    else:
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], True)

  if 'cameraSau' in item.keys():
    item['cameraSau'] = str(item['cameraSau']).strip()
  
  if 'cameraTruoc' in item.keys():
    item['cameraTruoc'] = str(item['cameraTruoc']).strip()
  
  if 'chipset' in item.keys():
    item['chipset'] = str(item['chipset']).strip()

  if 'color' in item.keys():
    item['color'] = str(item['color']).strip()
  
  if 'image' in item.keys():
    item['image'] = str(item['image']).strip()
  
  if 'linkProduct' in item.keys():
    item['linkProduct'] = str(item['linkProduct']).strip()
  
  if 'manHinh' in item.keys():
    item['manHinh'] = str(item['manHinh']).strip()

  if 'name' in item.keys():
    item['name'] = str(item['name']).strip()
  
  if 'operating' in item.keys():
    item['operating'] = str(item['operating']).strip()
  
  if 'pin' in item.keys():
    item['pin'] = str(item['pin']).strip()

for item in list_database:
  clean_data(item)

def check_item(item):
  check = True
  if 'name' in item.keys():
    if item['name'] == '':
      check = False

  if 'linkProduct' in item.keys():
    if item['linkProduct'] == '':
      check = False
  
  if 'brand' in item.keys():
    if item['brand'] == '':
      check = False
  
  if 'ram' not in item.keys() or ('ram' in item.keys() and item['ram'] == ''):
    check = False
  
  if 'priceDiscount' in item.keys():
    if item['priceDiscount'] == '0':
      check = False  

  return check

list_database_new = []
for item in list_database:
  if check_item(item):
    list_database_new.append(item)

list_check = [False] * len(list_database_new)

list_all = []
for i in range(len(list_database_new)):
    if not list_check[i]:
        list_check[i] = True
        list_ele = []
        list_ele.append(list_database_new[i])
        print("******************************")  
        print( list_database_new[i]["name"], "||", list_database_new[i]["_id"])
        print("==========")
       
        count = 1
        for y in range(len(list_database_new)):
            if not list_check[y]:
                if data_matching(list_database_new[i], list_database_new[y], threshold_name=90, threshold_ram=99, threshold_rom=99):
                    count += 1
                    list_check[y] = True
                    list_ele.append(list_database_new[y])
                    print(list_database_new[y]["name"] , "||", list_database_new[y]["ram"], "||", list_database_new[y]["rom"], "||", list_database_new[y]["color"], "||", list_database_new[y]["_id"])
        
        list_all.append(list_ele)
        print("Count", count)
# Out:
# ******************************
# Samsung Galaxy A73 5G 8GB/128GB Chính Hãng || 63c8283fe970f0eed5dff849
# ==========
# Samsung Galaxy A73 5G 8GB/128GB Chính Hãng || 8GB || 128GB || Xanh Mint || 63c8283fe970f0eed5dff84a
# Samsung Galaxy A73 5G 8GB/128GB Chính Hãng || 8GB || 128GB || Đen Ghi || 63c82840e970f0eed5dff84e
# Samsung Galaxy A73 A736 5G 128GB Ram 8GB || 8GB || 128GB || White || 63c829e0e970f0eed5dff929
# Samsung Galaxy A73 A736 5G 128GB Ram 8GB || 8GB || 128GB || Gray || 63c829e0e970f0eed5dff92a
# Samsung Galaxy A73 A736 5G 128GB Ram 8GB || 8GB || 128GB || Mint || 63c829e0e970f0eed5dff92b
# Samsung Galaxy A73 A736 5G 128GB Ram 8GB (New - BH12T) || 8GB || 128GB || Mint || 63c829e1e970f0eed5dff92c
# Samsung Galaxy A73 Chính Hãng (8GB|128GB) (BHĐT) || 8GB || 128GB || xám || 63c82ad5e970f0eed5dffa12
# Samsung Galaxy A73 Chính Hãng (8GB|128GB) (BHĐT) || 8GB || 128GB || Xanh Mint || 63c82ad5e970f0eed5dffa14
# Samsung Galaxy A73 128GB Chính Hãng || 8GB || 128GB || xám || 63c82adbe970f0eed5dffa32
# Samsung Galaxy A73 128GB Chính Hãng || 8GB || 128GB || trắng || 63c82adce970f0eed5dffa39
# Samsung Galaxy A73 128GB Chính Hãng || 8GB || 128GB || Xanh Mint || 63c82adde970f0eed5dffa3f
# Điện thoại Samsung A73 8GB/128GB Xanh || 8GB || 128GB || Xanh || 63c82b11e970f0eed5dffa66
# Điện thoại Samsung A73 8GB/128GB Xám || 8GB || 128GB || Xám || 63c82b13e970f0eed5dffa6c
# Điện thoại Samsung A73 8GB/128GB Trắng || 8GB || 128GB || Trắng || 63c82b2be970f0eed5dffab7
# samsung galaxy a73 5g - chính hãng || 8GB || 128GB || Xanh || 63c82b59e970f0eed5dffb1f
# samsung galaxy a73 5g - chính hãng || 8GB || 128GB || Trắng || 63c82b59e970f0eed5dffb24
# samsung galaxy a73 5g - chính hãng || 8GB || 128GB || Xám || 63c82b5ae970f0eed5dffb2e
# Samsung Galaxy A73 (5G) 8GB 128GB Chính hãng || 8GB || 128GB || Black || 63c82ba7e970f0eed5dffd53
# Samsung Galaxy A73 (5G) 8GB 128GB Chính hãng || 8GB || 128GB ||
# ==========
# iPhone 14 Plus 128GB | Chính hãng VN/A || 4GB || 128GB || Tím || 63c82bfee970f0eed5dffef9
# iPhone 14 Plus 128GB | Chính hãng VN/A || 4GB || 128GB || Trắng || 63c82bfee970f0eed5dffefb
# iPhone 14 Plus 128GB | Chính hãng VN/A || 4GB || 128GB || Đỏ || 63c82bffe970f0eed5dfff00
# Count 4
# ******************************
# POCO X4 GT || 63c82c01e970f0eed5dfff16
# ==========
# POCO X4 GT || 8GB || 128GB || Xanh || 63c82c01e970f0eed5dfff19
# POCO X4 GT || 8GB || 128GB || Bạc || 63c82c01e970f0eed5dfff1e
# Count 3
# ******************************
# Samsung Galaxy A04s || 63c82c03e970f0eed5dfff28
# ==========
# Samsung Galaxy A04s || 3GB || 32GB || Đồng || 63c82c03e970f0eed5dfff2a
# Samsung Galaxy A04s || 3GB || 32GB || Xanh || 63c82c03e970f0eed5dfff2c
# Count 3
# ******************************
# Xiaomi Redmi Note 11 Pro Plus 5G || 63c82c04e970f0eed5dfff2e
# ==========
# Count 1
# ******************************
# Xiaomi Redmi Note 11S || 63c82c05e970f0eed5dfff38
# ==========
# Count 1
# ******************************
# ASUS ROG Phone 6 12GB 256GB || 63c82c05e970f0eed5dfff42
# ==========
# ASUS ROG Phone 6 12GB 256GB || 12GB || 256GB || Trắng || 63c82c07e970f0eed5dfff54
# ASUS ROG Phone 6 Batman 12GB 256GB || 12GB || 256GB || Xám || 63c82c0fe970f0eed5dfff9f
# Count 3
# ******************************
# Samsung Galaxy A73 128GB || 63c82c06e970f0eed5dfff4d
# ==========
# Samsung Galaxy A73 128GB || 8GB || 64GB || Trắng || 63c82c06e970f0eed5dfff4e
# Count 2
# ******************************
# ASUS ROG Phone 6 16GB 512GB || 63c82c07e970f0eed5dfff56
# ==========
# ASUS ROG Phone 6 16GB 512GB || 16GB || 512GB || Trắng || 63c82c07e970f0eed5dfff58
# Count 2
# ******************************
# iPhone 14 Plus 256GB | Chính hãng VN/A || 63c82c08e970f0eed5dfff60
# ==========
# iPhone 14 Plus 256GB | Chính hãng VN/A || 4GB || 256GB || Tím || 63c82c08e970f0eed5dfff61
# iPhone 14 Plus 256GB | Chính hãng VN/A || 4GB || 256GB || Trắng || 63c82c08e970f0eed5dfff62
# iPhone 14 Plus 256GB | Chính hãng VN/A || 4GB || 256GB || Đen || 63c82c08e970f0eed5dfff63
# iPhone 14 Plus 256GB | Chính hãng VN/A || 4GB || 256GB || Xanh || 63c82c08e970f0eed5dfff66
# Count 5
# ******************************
# Realme C35 4GB 64GB || 63c82c08e970f0eed5dfff64
# ==========
# Count 1
# ******************************
# OPPO Reno8 5G 8GB 256GB || 63c82c0ae970f0eed5dfff70
# ==========
# OPPO Reno8 5G 8GB 256GB || 12GB || 256GB || Đen || 63c82c0be970f0eed5dfff81
# OPPO Reno8 Pro 5G 12GB 256GB || 12GB || 256GB || Xanh || 63c82c13e970f0eed5dfffc4
# Count 3
# ******************************
# OnePlus Nord CE 5G || 63c82c18e970f0eed5dffff1
# ==========
# Count 1
# ******************************
# Xiaomi Redmi 9T 4GB 64GB || 63c82c18e970f0eed5dffff2
# ==========
# Xiaomi Redmi 9T 4GB 64GB || 4GB || 64GB || Xám || 63c82c18e970f0eed5dffff3
# Xiaomi Redmi 9T 4GB 64GB || 4GB || 64GB || Xanh dương || 63c82c18e970f0eed5dffff6
# Count 3
# ******************************
# Vivo Y02 || 63c82c19e970f0eed5dffff8
# ==========
# Vivo Y02 || 2GB || 32GB || Đen/Xám || 63c82c1be970f0eed5e0000f
# Count 2
# ******************************
# Vsmart Aris 8GB 128GB || 63c82c19e970f0eed5e00000
# ==========
# Count 1
# ******************************
# Realme 8 5G || 63c82c1ae970f0eed5e00002
# ==========
# Count 1
# ******************************
# Nokia C30 2GB 32GB || 63c82c1ae970f0eed5e00005
# ==========
# Count 1
# ******************************
# Realme 9i 4GB 64GB || 63c82c1ae970f0eed5e00006
# ==========
# Realme 9i 4GB 64GB || 4GB || 32GB || Xanh || 63c82c1be970f0eed5e00014
# Count 2
# ******************************
# Realme C11 2021 4GB 64GB || 63c82c1ae970f0eed5e00009
# ==========
# Count 1
# ******************************
# Realme C25Y 4GB 64GB || 63c82c1ce970f0eed5e0001a
# ==========
# Realme C25Y 4GB 64GB || 4GB || 64GB || Xám || 63c82c1ce970f0eed5e0001d
# Count 2
# ******************************
# Vsmart Joy 4 4GB || 63c82c1ce970f0eed5e0001c
# ==========
# Count 1
# ******************************
# Samsung Galaxy S20+ (Plus) - Cũ trầy xước || 63c82c1ce970f0eed5e00021
# ==========
# Count 1
# ******************************
# Samsung Galaxy A14 5G || 63c82c1ce970f0eed5e00022
# ==========
# Samsung Galaxy A14 5G || 4GB || 64GB || Đen || 63c82c1ce970f0eed5e00023
# Count 2

# %%
len(list_all)
# Out:
# 282

# %%
for list in list_all:
    for item in list:
        if str(item['_id']) == '63c82abbe970f0eed5dff994':
            for temp in list:
                if temp['color'] == 'Xám':
                    print(temp["color"], "||", temp["namePage"], "||", temp["_id"], temp["name"] , "||", temp["ram"], "||", temp["rom"])
            break

# %%
for item in list_database:
    if str(item["_id"]) == "63c82bd0e970f0eed5dffe0f":
        print(item)
        item_one = item
        print(item["name"] , "||", item["ram"], "||", item["rom"], "||", item["color"], "||", item["_id"], "||", item["namePage"], item["linkProduct"])
# Out:
# {'_id': ObjectId('63c82bd0e970f0eed5dffe0f'), 'namePage': 'ClickBuy', 'image': 'https://clickbuy.cdn.vccloud.vn/uploads/2022/11/ava-note11tpro-150x150.png', 'color': 'Black', 'priceDiscount': '5590000', 'price': '6990000', 'linkProduct': 'https://clickbuy.com.vn/xiaomi-redmi-note-11t-pro-6gb-128gb-box/', 'name': 'Xiaomi Redmi Note 11T Pro 6Gb 128GB Box', 'brand': 'xiaomi', 'rom': '128GB', 'ram': '6GB', 'cameraSau': '64MP – 8MP – 2MP', 'cameraTruoc': '16 MP', 'chipset': 'MediaTek Dimensity 8100 (5 nm)', 'manHinh': '6.6 inches', 'operating': 'Androi 12, MIUI 13', 'pin': '5080mAh'}
# Xiaomi Redmi Note 11T Pro 6Gb 128GB Box || 6GB || 128GB || Black || 63c82bd0e970f0eed5dffe0f || ClickBuy https://clickbuy.com.vn/xiaomi-redmi-note-11t-pro-6gb-128gb-box/

# %%
63c8283fe970f0eed5dff84c, 63c82b5ae970f0eed5dffb32
63c8283fe970f0eed5dff84d, 63c82b64e970f0eed5dffba4
63c8283fe970f0eed5dff84d, 63c82846e970f0eed5dff881
63c8283fe970f0eed5dff84d, 63c82ba1e970f0eed5dffd2d
63c82adbe970f0eed5dffa33, 63c82bcae970f0eed5dffdf2
63c82b5ee970f0eed5dffb59, 63c82b85e970f0eed5dffccc
63c82bcee970f0eed5dffe05, 63c82bcfe970f0eed5dffe0c

nhan la 0

# %%
# Python code to
# demonstrate readlines()

  
# Using readlines()
file1 = open('test.txt', 'r')
Lines = file1.readlines()
  
count = 0
list_id = []
# Strips the newline character
for line in Lines:
   
    list_id.append(line.split("||")[-1].replace('\n', '').replace(' ', ''))

# %%
for item in list_database:
    if str(item["_id"]) in list_id:
        if "ram" in item and item["ram"] != '':
            
            print(item["name"] , "||", item["_id"])
# Out:
# Xiaomi Pad 5 Chính Hãng Màn 11" Ram 6G/128GB, Snap 860 - Bảo Hành 18 Tháng || 63c8284ae970f0eed5dff8a4
# Apple iPhone 13 Pro 1 sim 256GB || 63c829b6e970f0eed5dff8e9
# Apple iPhone 12 Pro 128GB VN/A || 63c829b7e970f0eed5dff8ea
# Apple iPhone 13 128GB VN/A || 63c829cce970f0eed5dff90c
# Apple iPhone 12 Mini 256Gb VN/A || 63c829cfe970f0eed5dff916
# Samsung Galaxy Z Flip3 5G F711 256GB Ram 8GB || 63c829d0e970f0eed5dff917
# Apple iPhone XS Max 1 Sim 64Gb || 63c829d1e970f0eed5dff919
# Apple iPhone SE 2020 64GB || 63c829dee970f0eed5dff928
# OPPO Reno8z 256GB Ram 8GB || 63c829e2e970f0eed5dff92d
# OPPO A77S 128GB RAM 8GB || 63c829f2e970f0eed5dff942
# OPPO A16 32GB RAM 3GB || 63c82a06e970f0eed5dff95c
# Nokia G11 Plus 64GB Ram 3GB || 63c82a0ae970f0eed5dff963
# Nokia C30 32GB RAM 3GB || 63c82a0ae970f0eed5dff965
# Xiaomi Redmi 10A 32GB RAM 2GB || 63c82a13e970f0eed5dff96b
# Nokia 8210 4G || 63c82a1be970f0eed5dff976
# Nokia 110 Dual (2021) || 63c82a1de970f0eed5dff977
# Nokia 105 Dual (2021) || 63c82a1ee970f0eed5dff97a
# iPhone 14 Pro 1TB Chính Hãng (VN/A) || 63c82ab9e970f0eed5dff987
# OPPO A95 4G 128GB Chính Hãng || 63c82ac3e970f0eed5dff9bf
# OPPO Reno6 5G 128GB Chính Hãng || 63c82ac3e970f0eed5dff9c2
# Nokia C01 Plus (2GB|16GB) Chính Hãng || 63c82ad0e970f0eed5dff9f8
# Vivo Y21s 128GB Chính Hãng || 63c82ad1e970f0eed5dffa02
