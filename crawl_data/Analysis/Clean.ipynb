# %% [markdown]
# ### brand:
#
#     xoa khoang trang 2 dau
#
#     tach dua tren khoang trang va lay tu dau tien
#
#     chuyen tat ca ve chu thuong
#
#     chuyen 'iphone' ve 'apple'

# %%
def clean_brand(brand):
  brand = str(brand).strip().split()[0].lower()
  if brand == 'iphone':
    brand = 'apple'
  
  return brand

print(clean_brand('Xiaomi'))
# Out:
# xiaomi

# %% [markdown]
# priceDiscount:
#
#     Liên hệ
#
#     2.590.000đ

# %%
def clean_price_discount(priceDiscount, check):
  if check:
    list_word = ["Liên", "hệ"]
    priceDiscount = str(priceDiscount).strip().replace('.', '').replace('đ', '')
    for word in list_word:
      if word in priceDiscount:
          priceDiscount = 0
          break
    return str(priceDiscount)
  else:
    priceDiscount = str(priceDiscount).strip().replace('đ', '').split('.')[0]
    return str(priceDiscount)
 
print(clean_price_discount('2590000.0đ', False))
# Out:
# 2590000

# %% [markdown]
# price:
#
#     trong thi lay priceDiscount
#
#     33.990.000đ

# %%
def clean_price(price, check):
  if check:
    price = str(price).strip().replace('.', '').replace('đ', '')
  else:
    price = str(price).strip().replace('đ', '').split('.')[0]
  return str(price)

print(clean_price('2590000.0đ', False))
# Out:
# 2590000

# %% [markdown]
# RAM:
#
#     trong thi bo
#
#     12GB LPDDR5
#
#     12GB LPDDR5
#
#     6 GB
#
#     48 MB
#
#     8Gb
#
#     8 GB, công nghệ mở rộng Ram 3G
#
#     16MB
#
#     8GB
#
#     4GB
#
#     4 GB ~ 7GB ( Bao gồm cả RAM ảo)
#
#     4GB + Mở rộng 3GB
#
#     4GB(+1GB)
#
#     8GB, LPDDR4X @ 2133MHz 2×16bit
#
#     +8GB mở rộng
#
#     Không
#
#     Đang cập nhật
#
#     6GB + Mở rộng 5GB
#
#     8GB + Mở rộng 8GB
#
#     12 GB + 3 GB (RAM bổ sung)

# %%
import re
temp = [ '4   gb', 'abc', '4m', '4g', '12GB LPDDR5', '12GB LPDDR5', '6 GB', '48 MB', '8Gb', '8 GB, công nghệ mở rộng Ram 3G', '16MB', '8GB', '4GB', '4 GB ~ 7GB ( Bao gồm cả RAM ảo)', 
'4GB + Mở rộng 3GB', '4GB(+1GB)', '8GB, LPDDR4X @ 2133MHz 2×16bit', '+8GB mở rộng', 'Không', 'Đang cập nhật', '6GB + Mở rộng 5GB', '8GB + Mở rộng 8GB', 
'12 GB + 3 GB (RAM bổ sung)' ]

def clean_ram(ram):
  ram = str(ram).strip().upper()
  if 'GB' in ram or 'G' in ram:
    ram = ram.split()[0].replace('G', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "GB"
      return ram
  
  if 'MB' in ram or 'M' in ram:
    ram = ram.split()[0].replace('M', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "MB"
      return ram

  return ""
  
for item in temp:
  print(clean_ram(item))
# Out:
# 4GB
#
# 4MB
# 4GB
# 12GB
# 12GB
# 6GB
# 48MB
# 8GB
# 8GB
# 16MB
# 8GB
# 4GB
# 4GB
# 4GB
# 4GB
# 8GB
# 8GB
#
#
# 6GB
# 8GB
# 12GB

# %% [markdown]
# ROM:
#     trong thi bo
#
#     1 T
#
#     512GB
#
#     1TB
#
#     128GB UFS 3.1
#
#     256 GB UFS 3.1
#
#     128 MB
#
#     256GB, UFS 2.2 @ 1-lane Gear3
#
#     256GB
#
#     128GB & 256GB

# %%
import re
temp = ['G', 'M', 'T', '1 T', '512GB', '1TB', '128GB UFS 3.1', '256 GB UFS 3.1', '128 MB', '256GB, UFS 2.2 @ 1-lane Gear3', '256GB', '128GB & 256GB']

def clean_rom(rom):
  rom = str(rom).strip().upper()
  if 'GB' in rom or 'G' in rom:
    rom = rom.split()[0].replace('G', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "GB"
      return rom
  
  if 'MB' in rom or 'M' in rom:
    rom = rom.split()[0].replace('M', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "MB"
      return rom
  
  if 'TB' in rom or 'T' in rom:
    rom = rom.split()[0].replace('T', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "TB"
      return rom

  return ""
  
for item in temp:
  print(clean_rom(item))
# Out:
# 1TB
# 512GB
# 1TB
# 128GB
# 256GB
# 128MB
# 256GB
# 256GB
# 128GB

# %%
import re
from pymongo import MongoClient

client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db')
phones = db.data_phone_items
list_database = []
for item in list(phones.find()):
    list_database.append(item)

def clean_brand(brand):
  brand = str(brand).strip().split()[0].lower()
  if brand == 'iphone':
    brand = 'apple'
  return brand

def clean_price_discount(priceDiscount, check):
  if check:
    list_word = ["Liên", "hệ"]
    priceDiscount = str(priceDiscount).strip().replace('.', '').replace('đ', '')
    for word in list_word:
      if word in priceDiscount:
          priceDiscount = 0
          break
    return str(priceDiscount)
  else:
    priceDiscount = str(priceDiscount).strip().replace('đ', '').split('.')[0]
    return str(priceDiscount)

def clean_price(price, check):
  if check:
    price = str(price).strip().replace('.', '').replace('đ', '')
  else:
    price = str(price).strip().replace('đ', '').split('.')[0]
  return str(price)

def clean_ram(ram):
  ram = str(ram).strip().upper()
  if 'GB' in ram or 'G' in ram:
    ram = ram.split()[0].replace('G', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "GB"
      return ram
  
  if 'MB' in ram or 'M' in ram:
    ram = ram.split()[0].replace('M', '').replace('B', '').replace('+','')
    ram = re.sub("\(.*\)", "", ram)
    ram = re.sub("\,", "", ram)
    if ram != '' and ram.isnumeric():
      ram = ram + "MB"
      return ram

  return ""

def preprocessing_ram(item):
  if ("ram" not in item) or ("ram" in item and item["ram"] == None) :
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]

        if '-' in ram_rom:
            ram = re.split('[-]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '|' in ram_rom:
            ram = re.split('[|]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        elif '/' in ram_rom:
            ram = re.split('[/]', ram_rom)[0]
            item["ram"] = clean_ram(ram)
        else:
            ram = re.split('[\s]', ram_rom)[0]    
            item["ram"] = clean_ram(ram) 
  
  if "ram" in item:
    item['ram'] = clean_ram(item['ram'])

def clean_rom(rom):
  rom = str(rom).strip().upper()
  if 'GB' in rom or 'G' in rom:
    rom = rom.split()[0].replace('G', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "GB"
      return rom
  
  if 'MB' in rom or 'M' in rom:
    rom = rom.split()[0].replace('M', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "MB"
      return rom
  
  if 'TB' in rom or 'T' in rom:
    rom = rom.split()[0].replace('T', '').replace('B', '')
    rom = re.sub("\(.*\)", "", rom)
    rom = re.sub("\,", "", rom)
    if rom != '' and rom.isnumeric():
      rom = rom + "TB"
      return rom

  return ""

def preprocessing_rom(item):
  if ("rom" not in item) or ("rom" in item and item["rom"] == None):
    name = item["name"].lower()
    check_have_ram_rom = re.search("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)
    if check_have_ram_rom:
        ram_rom = re.findall("[0-9]+[mg]b[- / | \s]+[0-9]+[tmg][b]?", name)[0]
        if '-' in ram_rom:
            rom = re.split('[-]', ram_rom)[-1]
            item["rom"] = rom
        elif '|' in ram_rom:
            rom = re.split('[|]', ram_rom)[-1]
            item["rom"] = rom
        elif '/' in ram_rom:
            rom = re.split('[/]', ram_rom)[-1]
            item["rom"] = rom
        else:
            rom = re.split('[\s]', ram_rom)[-1]    
            item["rom"] = rom   
    else:
        check_have_rom = re.search("[0-9]+[tmg][b]", name)
        if check_have_rom:
            rom = re.findall("[0-9]+[tmg][b]", name)[0]
            item["rom"] = rom
  
  if "rom" in item:
    item['rom'] = clean_rom(item['rom'])

def clean_data(item):
  
  if 'brand' in item.keys():
    item['brand'] = clean_brand(item['brand'])

  preprocessing_ram(item)
  preprocessing_rom(item)
    
  if 'price' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['price'] = clean_price(item['price'], False)
    else:
        item['price'] = clean_price(item['price'], True)

  if 'priceDiscount' in item.keys():
    if item['namePage'] == 'CellphoneS':
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], False)
    else:
        item['priceDiscount'] = clean_price_discount(item['priceDiscount'], True)

  if 'cameraSau' in item.keys():
    item['cameraSau'] = str(item['cameraSau']).strip()
  
  if 'cameraTruoc' in item.keys():
    item['cameraTruoc'] = str(item['cameraTruoc']).strip()
  
  if 'chipset' in item.keys():
    item['chipset'] = str(item['chipset']).strip()

  if 'color' in item.keys():
    item['color'] = str(item['color']).strip()
  
  if 'image' in item.keys():
    item['image'] = str(item['image']).strip()
  
  if 'linkProduct' in item.keys():
    item['linkProduct'] = str(item['linkProduct']).strip()
  
  if 'manHinh' in item.keys():
    item['manHinh'] = str(item['manHinh']).strip()

  if 'name' in item.keys():
    item['name'] = str(item['name']).strip()
  
  if 'operating' in item.keys():
    item['operating'] = str(item['operating']).strip()
  
  if 'pin' in item.keys():
    item['pin'] = str(item['pin']).strip()

for item in list_database:
  clean_data(item)

# %%
def check_item(item):
  check = True
  if 'name' in item.keys():
    if item['name'] == '':
      check = False

  if 'linkProduct' in item.keys():
    if item['linkProduct'] == '':
      check = False
  
  if 'brand' in item.keys():
    if item['brand'] == '':
      check = False
  
  if 'priceDiscount' in item.keys():
    if item['priceDiscount'] == '0':
      check = False

  # if 'ram' in item.keys():
  #   if item['ram'] == '':
  #     check = False

  # if 'rom' in item.keys():
  #   if item['rom'] == '':
  #     check = False   

  return check

# %%
# insert vao database moi
# clean_database
uri_name = 'mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority'
db_name = 'data_phone_db_clean'
collection_name = 'data_phone_items_clean'

client = MongoClient(uri_name)
db = client[db_name]
db[collection_name].delete_many({})

for item in list_database:
  if check_item(item):
    db[collection_name].insert_one(dict(item))

# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db')
phones = db.data_phone_items

list_database = []
for item in list(phones.find()):
    list_database.append(item)

# %%
client = MongoClient("mongodb+srv://hoang:hoang@cluster0.vwzhu.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('data_phone_db_clean')
phones = db.data_phone_items_clean

list_database_clean = []
for item in list(phones.find()):
    list_database_clean.append(item)

# %%
unique_brand_clean = []
for item in list_database_clean:
    if "brand" in item.keys():
        if item["brand"] not in unique_brand_clean:
            unique_brand_clean.append(item["brand"])

# %%
unique_brand_clean
# Out:
# ['samsung',
#  'xiaomi',
#  'apple',
#  'oppo',
#  'poco',
#  'realme',
#  'máy',
#  'nokia',
#  'vivo',
#  'tecno',
#  'philips',
#  'bphone',
#  'xor',
#  'masstel',
#  'itel',
#  'nubia',
#  'tcl',
#  'dộng',
#  'redmi',
#  'energizer',
#  'công',
#  'lenovo',
#  'asus',
#  'oneplus',
#  'vsmart']

# %%
unique_brand = []
for item in list_database:
    if "brand" in item.keys():
        if item["brand"] not in unique_brand:
            unique_brand.append(item["brand"])

# %%
print(unique_brand)
# Out:
# ['Samsung', 'Xiaomi', 'Apple', 'Oppo', 'POCO', 'Realme', 'Máy tính bảng khác', 'Samsung Cũ', 'Apple iPhone', 'Nokia - Microsoft', 'OPPO', 'Vivo', 'Nokia', ' Xiaomi ', ' Samsung ', ' Nokia ', ' iPhone ', ' OPPO ', ' Vivo ', ' Realme ', 'samsung', 'xiaomi', 'oppo', 'tecno', 'apple', 'nokia', 'vivo', 'realme', 'philips', 'poco', 'bphone', 'xor', 'masstel', 'itel', 'nubia', 'tcl', 'dộng', 'redmi', 'energizer', 'Apple iPad', 'Công ty cũ', 'Lenovo Tab', 'Samsung tab', 'Samsung cũ', 'Bphone', 'ASUS', 'Tecno', 'Oneplus', 'Nubia', 'OnePlus', 'Vsmart']

# %%
for item in list_database:
    if "brand" in item.keys():
        if item["brand"] == 'Máy tính bảng khác':
            print(item)
# Out:
# {'_id': ObjectId('63c8284ae970f0eed5dff8a4'), 'namePage': 'Di Động Thông Minh', 'image': 'https://didongthongminh.vn/images/products/2022/02/05/resized/thiết-kế-không-tên-33_1644054485.webp', 'color': 'Xám', 'priceDiscount': '8290000', 'linkProduct': 'https://didongthongminh.vn/xiaomi-pad-5-6gb-128gb-chinh-hang', 'name': 'Xiaomi Pad 5 Chính Hãng Màn 11" Ram 6G/128GB, Snap 860 - Bảo Hành 18 Tháng', 'brand': 'Máy tính bảng khác', 'manHinh': '11" - Tần số quét\xa0120 Hz', 'operating': 'Android 12', 'chipset': 'Snapdragon 860 8 nhân', 'ram': '6 GB', 'rom': '128 GB', 'pin': '8721 mAh', 'cameraTruoc': '9 MP', 'cameraSau': '14 MP'}
